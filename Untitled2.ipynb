# %% [markdown]
# <a href="https://colab.research.google.com/github/SVG-campus/77/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the required libraries
# !pip install -q TTS
# !pip install -q pydub

import os
import re
import shutil
import glob
import numpy as np
from TTS.api import TTS
from pydub import AudioSegment
import torch
from IPython.display import Audio

def text_to_audiobook_coqui(input_file, output_dir, chunk_size=1500, model_name="tts_models/en/ljspeech/tacotron2-DDC"):
    """
    Convert a text file into an audiobook using Coqui TTS

    Parameters:
    input_file (str): Path to the text file
    output_dir (str): Directory path for the output audio file
    chunk_size (int): Number of characters to process at once
    model_name (str): Name of the TTS model to use
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Generate output filename based on input file
    filename = os.path.basename(input_file).split('.')[0]
    output_file = os.path.join(output_dir, f"{filename}.mp3")

    # Clean up any previous temp directory
    temp_dir = 'temp_audio'
    if os.path.exists(temp_dir):
        shutil.rmtree(temp_dir, ignore_errors=True)
    os.makedirs(temp_dir, exist_ok=True)

    print("Reading text file...")
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            text = f.read()
    except UnicodeDecodeError:
        # Try different encodings if utf-8 fails
        try:
            with open(input_file, 'r', encoding='latin-1') as f:
                text = f.read()
        except:
            with open(input_file, 'r', encoding='cp1252') as f:
                text = f.read()

    # Clean the text (remove extra whitespace, etc.)
    text = re.sub(r'\s+', ' ', text).strip()

    # List available models and select a female voice model
    print("Loading TTS model...")

    # Initialize TTS with the specified model
    tts = TTS(model_name=model_name)

    # Show available models
    print("\nAvailable TTS models:")
    print(f"Currently using: {model_name}")
    print("You can change the model by modifying the model_name parameter")

    # Let's get some female voice models
    female_models = [
        "tts_models/en/ljspeech/tacotron2-DDC",          # LJSpeech - Female voice
        "tts_models/en/ljspeech/glow-tts",               # Another female voice model
        "tts_models/en/vctk/vits",                       # Multi-speaker model with female options
    ]
    print("\nRecommended female voice models:")
    for model in female_models:
        print(f" - {model}")

    # Split text into sentences or logical chunks
    print("Processing text into chunks...")

    # Use regex to split by sentence endings
    sentence_pattern = r'(?<=[.!?])\s+'
    sentences = re.split(sentence_pattern, text)

    # Group sentences into chunks that don't exceed chunk_size
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= chunk_size:
            current_chunk += sentence + " "
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            current_chunk = sentence + " "

    # Add the last chunk if it's not empty
    if current_chunk:
        chunks.append(current_chunk.strip())

    print(f"Converting {len(chunks)} text chunks to speech...")

    # Convert each chunk to speech
    audio_files = []
    for i, chunk in enumerate(chunks):
        if not chunk.strip():  # Skip empty chunks
            continue

        print(f"Processing chunk {i+1}/{len(chunks)}...")
        chunk_file = os.path.join(temp_dir, f"chunk_{i}.wav")

        try:
            # Generate speech
            tts.tts_to_file(text=chunk, file_path=chunk_file)

            # Convert wav to mp3 and add to list
            chunk_mp3_file = os.path.join(temp_dir, f"chunk_{i}.mp3")
            audio = AudioSegment.from_wav(chunk_file)
            audio.export(chunk_mp3_file, format="mp3")
            audio_files.append(chunk_mp3_file)

            # Save progress periodically
            if i > 0 and i % 10 == 0:
                print(f"Saving progress up to chunk {i}...")
                interim_file = os.path.join(output_dir, f"{filename}_part_{i//10}.mp3")
                combine_audio_files(audio_files[-10:], interim_file)

        except Exception as e:
            print(f"Error processing chunk {i+1}: {str(e)}")
            print("Continuing with next chunk...")
            continue

    # Combine all audio files into final output
    if audio_files:
        print("Combining all audio chunks...")
        combine_audio_files(audio_files, output_file)
        print(f"Audiobook creation complete! File saved to {output_file}")
    else:
        print("No audio files were created successfully.")

    # Clean up temp directory safely
    try:
        # Remove individual files first
        for file_path in glob.glob(os.path.join(temp_dir, '*')):
            try:
                os.remove(file_path)
            except:
                pass
        # Then try to remove the directory
        try:
            os.rmdir(temp_dir)
        except:
            print(f"Warning: Could not remove temp directory. You may need to manually delete {temp_dir}")
    except Exception as e:
        print(f"Warning: Error during cleanup: {str(e)}")

    return output_file

def combine_audio_files(audio_files, output_file):
    """Combine multiple audio files into one"""
    if not audio_files:
        print("No audio files to combine.")
        return None

    combined = AudioSegment.empty()
    processed_files = 0

    for audio_file in audio_files:
        if os.path.exists(audio_file):
            try:
                segment = AudioSegment.from_mp3(audio_file)
                combined += segment
                processed_files += 1
            except Exception as e:
                print(f"Error processing {audio_file}: {str(e)}")

    print(f"Successfully combined {processed_files} audio files out of {len(audio_files)}.")

    if processed_files > 0:
        print(f"Saving audio to {output_file}...")
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        combined.export(output_file, format="mp3")
        print(f"Total duration: {len(combined)/1000/60:.2f} minutes")
        return output_file
    else:
        print("No files were successfully processed.")
        return None

def create_preview(tts, text, output_file):
    """Create a preview audio sample"""
    try:
        # Take first paragraph or about 500 characters
        preview_text = text[:500].strip()
        tts.tts_to_file(text=preview_text, file_path=output_file)
        return True
    except Exception as e:
        print(f"Error creating preview: {str(e)}")
        return False

# Specific paths for Frankenstein
input_text_file = '/content/Books/Frankenstein/84-0.txt'
output_dir = '/content/Audiobooks/Frankenstein'

# Check for CUDA/GPU availability for faster processing
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# Read a sample of text for preview
try:
    with open(input_text_file, 'r', encoding='utf-8') as f:
        sample_text = f.read(1000)
except:
    with open(input_text_file, 'r', encoding='latin-1') as f:
        sample_text = f.read(1000)

# Create a preview with different models to let user choose
print("\nCreating previews with different female voice models...")

# Models to try (all female voices)
models_to_try = [
    "tts_models/en/ljspeech/tacotron2-DDC",
    "tts_models/en/ljspeech/glow-tts"
]

for i, model in enumerate(models_to_try):
    preview_file = f"/content/preview_model_{i+1}.wav"
    try:
        print(f"\nTrying model: {model}")
        tts = TTS(model_name=model, progress_bar=True)
        tts.tts_to_file(text=sample_text[:200], file_path=preview_file)
        print(f"Preview {i+1} created with {model}")
        display(Audio(preview_file, autoplay=False))
    except Exception as e:
        print(f"Error with model {model}: {str(e)}")

print("\nPlease run this cell, listen to the previews, and choose your preferred voice model.")
print("Then run the cell below with your chosen model to generate the full audiobook.")

# Now give code to generate the full audiobook with the chosen model
print("""
# Generate full audiobook with your preferred model
# Replace the model_name with your choice

selected_model = "tts_models/en/ljspeech/tacotron2-DDC"  # Change this to your preferred model

output_file = text_to_audiobook_coqui(
    input_file='/content/Books/Frankenstein/84-0.txt',
    output_dir='/content/Audiobooks/Frankenstein',
    chunk_size=1500,  # Smaller chunks for better quality
    model_name=selected_model
)

if output_file and os.path.exists(output_file):
    print(f"Preview of final audiobook:")
    display(Audio(output_file, autoplay=False))
""")
# Out:
# Using device: cpu
#
# Creating previews with different female voice models...
#
# Trying model: tts_models/en/ljspeech/tacotron2-DDC
#  > Downloading model to /root/.local/share/tts/tts_models--en--ljspeech--tacotron2-DDC
#  99%|█████████▉| 112M/113M [00:01<00:00, 58.8MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Downloading model to /root/.local/share/tts/vocoder_models--en--ljspeech--hifigan_v2
# 100%|██████████| 113M/113M [00:02<00:00, 39.0MiB/s]
#
#  59%|█████▊    | 2.23M/3.80M [00:00<00:00, 22.3MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Using model: Tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
# /usr/local/lib/python3.11/dist-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
#  > Model's reduction rate `r` is set to: 1
#  > Vocoder Model: hifigan
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: hifigan_generator
#  > Discriminator Model: hifigan_discriminator
# Removing weight norm...
#  > Text splitted to sentences.
# ['*** START OF THE PROJECT GUTENBERG EBOOK 84 ***', 'Frankenstein;', 'or, the Modern Prometheus', 'by Mary Wollstonecraft (Godwin) Shelley', 'CONTENTS', 'Letter 1', 'Letter 2', 'Letter 3', 'Letter 4', 'Chapter 1', 'Chap']
# *** start of the project gutenberg ebook eighty four ***
#  [!] Character '*' not found in the vocabulary. Discarding it.
# 100%|██████████| 3.80M/3.80M [00:17<00:00, 22.3MiB/s]
#    > Decoder stopped with `max_decoder_steps` 10000

# %%
import os
import re
import csv
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Create necessary directories
os.makedirs('/content/Books', exist_ok=True)

# Function to sanitize filenames (remove characters not allowed in directory names)
def sanitize_filename(name):
    return re.sub(r'[\\/*?:"<>|]', "", name)

# Function to extract book ID from URL
def extract_book_id(url):
    match = re.search(r'/epub/(\d+)/', url)
    if match:
        return match.group(1)
    else:
        match = re.search(r'ebooks/(\d+)', url)
        if match:
            return match.group(1)
    return None

# Function to download file
def download_file(url, destination):
    response = requests.get(url)
    if response.status_code == 200:
        with open(destination, 'wb') as f:
            f.write(response.content)
        return True
    return False

# Base URL
base_url = "https://www.gutenberg.org"

# URL of the top 100 page
top_100_url = f"{base_url}/browse/scores/top"

# List to store all the book data
books_data = []

# Get the top 100 page
print("Accessing Top 100 page...")
response = requests.get(top_100_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the section with "Top 100 EBooks last 30 days"
top_books_section = None
for h2 in soup.find_all('h2'):
    if "Top 100 EBooks last 30 days" in h2.text:
        top_books_section = h2.find_next('ol')
        break

if not top_books_section:
    print("Could not find the Top 100 books section.")
    exit(1)

# Extract all book links from this section
book_links = []
for li in top_books_section.find_all('li'):
    link = li.find('a')
    if link and link.get('href'):
        book_links.append(urljoin(base_url, link.get('href')))

# Process each book
for i, book_url in enumerate(book_links, 1):
    try:
        print(f"Processing book {i} of {len(book_links)}: {book_url}")

        # Get the book page
        response = requests.get(book_url)
        if response.status_code != 200:
            print(f"Failed to access {book_url}")
            continue

        book_soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the title
        title_element = book_soup.find('h1', {'itemprop': 'name'})
        if not title_element:
            print(f"Could not find title for book at {book_url}")
            continue

        title = title_element.text.strip()
        print(f"Found book: {title}")

        # Look for the Plain Text UTF-8 link
        plain_text_link = None
        for link in book_soup.find_all('a', {'type': 'text/plain; charset=us-ascii', 'class': 'link'}):
            if "Plain Text UTF-8" in link.text:
                plain_text_link = urljoin(base_url, link.get('href'))
                break

        if not plain_text_link:
            print(f"Could not find Plain Text UTF-8 link for {title}")
            continue

        # Extract book ID
        book_id = extract_book_id(plain_text_link)
        if not book_id:
            print(f"Could not extract book ID from {plain_text_link}")
            continue

        # Create sanitized folder name
        folder_name = sanitize_filename(title)
        folder_path = os.path.join('/content/Books', folder_name)
        os.makedirs(folder_path, exist_ok=True)

        # Get the actual filename from the Plain Text UTF-8 link
        response = requests.get(plain_text_link, allow_redirects=True)
        if response.status_code != 200:
            print(f"Failed to access Plain Text UTF-8 file for {title}")
            continue

        # Get the final URL after redirects
        final_url = response.url

        # Extract the filename from the final URL
        filename = os.path.basename(final_url)

        # If the filename doesn't end with .txt, add it
        if not filename.endswith('.txt'):
            filename = f"{filename}.txt"

        # Store the actual text content
        destination = os.path.join(folder_path, filename)
        with open(destination, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded text to {destination}")

        # Store the book information
        books_data.append({
            'Title': title,
            'Number': book_id,
            'Filename': filename
        })

        # Add a small delay to avoid hammering the server
        time.sleep(1)

    except Exception as e:
        print(f"Error processing {book_url}: {str(e)}")

# Write the CSV file
csv_path = '/content/gutenberg_top100.csv'
with open(csv_path, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Title', 'Number', 'Filename']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for book in books_data:
        writer.writerow(book)

print(f"CSV file created at {csv_path}")
print(f"Downloaded {len(books_data)} out of {len(book_links)} books")
# Out:
# Accessing Top 100 page...
# Processing book 1 of 100: https://www.gutenberg.org/ebooks/26184
# Found book: Simple Sabotage Field Manual by United States. Office of Strategic Services
# Downloaded text to /content/Books/Simple Sabotage Field Manual by United States. Office of Strategic Services/pg26184.txt
# Processing book 2 of 100: https://www.gutenberg.org/ebooks/84
# Found book: Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley
# Downloaded text to /content/Books/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley/pg84.txt
# Processing book 3 of 100: https://www.gutenberg.org/ebooks/2701
# Found book: Moby Dick; Or, The Whale by Herman Melville
# Downloaded text to /content/Books/Moby Dick; Or, The Whale by Herman Melville/pg2701.txt
# Processing book 4 of 100: https://www.gutenberg.org/ebooks/1513
# Found book: Romeo and Juliet by William Shakespeare
# Downloaded text to /content/Books/Romeo and Juliet by William Shakespeare/pg1513.txt
# Processing book 5 of 100: https://www.gutenberg.org/ebooks/1342
# Found book: Pride and Prejudice by Jane Austen
# Downloaded text to /content/Books/Pride and Prejudice by Jane Austen/pg1342.txt
# Processing book 6 of 100: https://www.gutenberg.org/ebooks/11
# Found book: Alice's Adventures in Wonderland by Lewis Carroll
# Downloaded text to /content/Books/Alice's Adventures in Wonderland by Lewis Carroll/pg11.txt
# Processing book 7 of 100: https://www.gutenberg.org/ebooks/64317
# Found book: The Great Gatsby by F. Scott Fitzgerald
# Downloaded text to /content/Books/The Great Gatsby by F. Scott Fitzgerald/pg64317.txt
# Processing book 8 of 100: https://www.gutenberg.org/ebooks/100
# Found book: The Complete Works of William Shakespeare by William Shakespeare
# Downloaded text to /content/Books/The Complete Works of William Shakespeare by William Shakespeare/pg100.txt
# Processing book 9 of 100: https://www.gutenberg.org/ebooks/2542
# Found book: A Doll's House : a play by Henrik Ibsen
# Downloaded text to /content/Books/A Doll's House  a play by Henrik Ibsen/pg2542.txt
# Processing book 10 of 100: https://www.gutenberg.org/ebooks/145
# Found book: Middlemarch by George Eliot
# Downloaded text to /content/Books/Middlemarch by George Eliot/pg145.txt
# Processing book 11 of 100: https://www.gutenberg.org/ebooks/2641
# Found book: A Room with a View by E. M. Forster
# Downloaded text to /content/Books/A Room with a View by E. M. Forster/pg2641.txt
# Processing book 12 of 100: https://www.gutenberg.org/ebooks/37106
# Found book: Little Women; Or, Meg, Jo, Beth, and Amy by Louisa May Alcott
# Downloaded text to /content/Books/Little Women; Or, Meg, Jo, Beth, and Amy by Louisa May Alcott/pg37106.txt
# Processing book 13 of 100: https://www.gutenberg.org/ebooks/174
# Found book: The Picture of Dorian Gray by Oscar Wilde
# Downloaded text to /content/Books/The Picture of Dorian Gray by Oscar Wilde/pg174.txt
# Processing book 14 of 100: https://www.gutenberg.org/ebooks/67979
# Found book: The Blue Castle: a novel by L. M. Montgomery
# Downloaded text to /content/Books/The Blue Castle a novel by L. M. Montgomery/pg67979.txt
# Processing book 15 of 100: https://www.gutenberg.org/ebooks/844
# Found book: The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde
# Downloaded text to /content/Books/The Importance of Being Earnest A Trivial Comedy for Serious People by Oscar Wilde/pg844.txt
# Processing book 16 of 100: https://www.gutenberg.org/ebooks/16389
# Found book: The Enchanted April by Elizabeth Von Arnim
# Downloaded text to /content/Books/The Enchanted April by Elizabeth Von Arnim/pg16389.txt
# Processing book 17 of 100: https://www.gutenberg.org/ebooks/1080
# Found book: A Modest Proposal by Jonathan Swift
# Downloaded text to /content/Books/A Modest Proposal by Jonathan Swift/pg1080.txt
# Processing book 18 of 100: https://www.gutenberg.org/ebooks/1952
# Found book: The Yellow Wallpaper by Charlotte Perkins Gilman
# Downloaded text to /content/Books/The Yellow Wallpaper by Charlotte Perkins Gilman/pg1952.txt
# Processing book 19 of 100: https://www.gutenberg.org/ebooks/43
# Found book: The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson
# Downloaded text to /content/Books/The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson/pg43.txt
# Processing book 20 of 100: https://www.gutenberg.org/ebooks/6761
# Found book: The Adventures of Ferdinand Count Fathom — Complete by T. Smollett
# Downloaded text to /content/Books/The Adventures of Ferdinand Count Fathom — Complete by T. Smollett/pg6761.txt
# Processing book 21 of 100: https://www.gutenberg.org/ebooks/394
# Found book: Cranford by Elizabeth Cleghorn Gaskell
# Downloaded text to /content/Books/Cranford by Elizabeth Cleghorn Gaskell/pg394.txt
# Processing book 22 of 100: https://www.gutenberg.org/ebooks/2160
# Found book: The Expedition of Humphry Clinker by T. Smollett
# Downloaded text to /content/Books/The Expedition of Humphry Clinker by T. Smollett/pg2160.txt
# Processing book 23 of 100: https://www.gutenberg.org/ebooks/6593
# Found book: History of Tom Jones, a Foundling by Henry Fielding
# Downloaded text to /content/Books/History of Tom Jones, a Foundling by Henry Fielding/pg6593.txt
# Processing book 24 of 100: https://www.gutenberg.org/ebooks/5197
# Found book: My Life — Volume 1 by Richard Wagner
# Downloaded text to /content/Books/My Life — Volume 1 by Richard Wagner/pg5197.txt
# Processing book 25 of 100: https://www.gutenberg.org/ebooks/4085
# Found book: The Adventures of Roderick Random by T. Smollett
# Downloaded text to /content/Books/The Adventures of Roderick Random by T. Smollett/pg4085.txt
# Processing book 26 of 100: https://www.gutenberg.org/ebooks/1259
# Found book: Twenty years after by Alexandre Dumas and Auguste Maquet
# Downloaded text to /content/Books/Twenty years after by Alexandre Dumas and Auguste Maquet/pg1259.txt
# Processing book 27 of 100: https://www.gutenberg.org/ebooks/345
# Found book: Dracula by Bram Stoker
# Downloaded text to /content/Books/Dracula by Bram Stoker/pg345.txt
# Processing book 28 of 100: https://www.gutenberg.org/ebooks/5200
# Found book: Metamorphosis by Franz Kafka
# Downloaded text to /content/Books/Metamorphosis by Franz Kafka/pg5200.txt
# Processing book 29 of 100: https://www.gutenberg.org/ebooks/2554
# Found book: Crime and Punishment by Fyodor Dostoyevsky
# Downloaded text to /content/Books/Crime and Punishment by Fyodor Dostoyevsky/pg2554.txt
# Processing book 30 of 100: https://www.gutenberg.org/ebooks/76
# Found book: Adventures of Huckleberry Finn by Mark Twain
# Downloaded text to /content/Books/Adventures of Huckleberry Finn by Mark Twain/pg76.txt
# Processing book 31 of 100: https://www.gutenberg.org/ebooks/25344
# Found book: The Scarlet Letter by Nathaniel Hawthorne
# Downloaded text to /content/Books/The Scarlet Letter by Nathaniel Hawthorne/pg25344.txt
# Processing book 32 of 100: https://www.gutenberg.org/ebooks/98
# Found book: A Tale of Two Cities by Charles Dickens
# Downloaded text to /content/Books/A Tale of Two Cities by Charles Dickens/pg98.txt
# Processing book 33 of 100: https://www.gutenberg.org/ebooks/408
# Found book: The Souls of Black Folk by W. E. B. Du Bois
# Downloaded text to /content/Books/The Souls of Black Folk by W. E. B. Du Bois/pg408.txt
# Processing book 34 of 100: https://www.gutenberg.org/ebooks/1260
# Found book: Jane Eyre: An Autobiography by Charlotte Brontë
# Downloaded text to /content/Books/Jane Eyre An Autobiography by Charlotte Brontë/pg1260.txt
# Processing book 35 of 100: https://www.gutenberg.org/ebooks/1232
# Found book: The Prince by Niccolò Machiavelli
# Downloaded text to /content/Books/The Prince by Niccolò Machiavelli/pg1232.txt
# Processing book 36 of 100: https://www.gutenberg.org/ebooks/1400
# Found book: Great Expectations by Charles Dickens
# Downloaded text to /content/Books/Great Expectations by Charles Dickens/pg1400.txt
# Processing book 37 of 100: https://www.gutenberg.org/ebooks/3207
# Found book: Leviathan by Thomas Hobbes
# Downloaded text to /content/Books/Leviathan by Thomas Hobbes/pg3207.txt
# Processing book 38 of 100: https://www.gutenberg.org/ebooks/50150
# Found book: The Devil is an Ass by Ben Jonson
# Downloaded text to /content/Books/The Devil is an Ass by Ben Jonson/pg50150.txt
# Processing book 39 of 100: https://www.gutenberg.org/ebooks/219
# Found book: Heart of Darkness by Joseph Conrad
# Downloaded text to /content/Books/Heart of Darkness by Joseph Conrad/pg219.txt
# Processing book 40 of 100: https://www.gutenberg.org/ebooks/41445
# Found book: Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley
# Downloaded text to /content/Books/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley/pg41445.txt
# Processing book 41 of 100: https://www.gutenberg.org/ebooks/1727
# Found book: The Odyssey by Homer
# Downloaded text to /content/Books/The Odyssey by Homer/pg1727.txt
# Processing book 42 of 100: https://www.gutenberg.org/ebooks/1998
# Found book: Thus Spake Zarathustra: A Book for All and None by Friedrich Wilhelm Nietzsche
# Downloaded text to /content/Books/Thus Spake Zarathustra A Book for All and None by Friedrich Wilhelm Nietzsche/pg1998.txt
# Processing book 43 of 100: https://www.gutenberg.org/ebooks/1184
# Found book: The Count of Monte Cristo by Alexandre Dumas and Auguste Maquet
# Downloaded text to /content/Books/The Count of Monte Cristo by Alexandre Dumas and Auguste Maquet/pg1184.txt
# Processing book 44 of 100: https://www.gutenberg.org/ebooks/28054
# Found book: The Brothers Karamazov by Fyodor Dostoyevsky
# Downloaded text to /content/Books/The Brothers Karamazov by Fyodor Dostoyevsky/pg28054.txt
# Processing book 45 of 100: https://www.gutenberg.org/ebooks/1661
# Found book: The Adventures of Sherlock Holmes by Arthur Conan Doyle
# Downloaded text to /content/Books/The Adventures of Sherlock Holmes by Arthur Conan Doyle/pg1661.txt
# Processing book 46 of 100: https://www.gutenberg.org/ebooks/2600
# Found book: War and Peace by graf Leo Tolstoy
# Downloaded text to /content/Books/War and Peace by graf Leo Tolstoy/pg2600.txt
# Processing book 47 of 100: https://www.gutenberg.org/ebooks/2000
# Found book: Don Quijote by Miguel de Cervantes Saavedra
# Downloaded text to /content/Books/Don Quijote by Miguel de Cervantes Saavedra/pg2000.txt
# Processing book 48 of 100: https://www.gutenberg.org/ebooks/7370
# Found book: Second Treatise of Government by John Locke
# Downloaded text to /content/Books/Second Treatise of Government by John Locke/pg7370.txt
# Processing book 49 of 100: https://www.gutenberg.org/ebooks/20228
# Found book: Noli Me Tangere by José Rizal
# Downloaded text to /content/Books/Noli Me Tangere by José Rizal/pg20228.txt
# Processing book 50 of 100: https://www.gutenberg.org/ebooks/2650
# Found book: Du côté de chez Swann by Marcel Proust
# Downloaded text to /content/Books/Du côté de chez Swann by Marcel Proust/pg2650.txt
# Processing book 51 of 100: https://www.gutenberg.org/ebooks/6130
# Found book: The Iliad by Homer
# Downloaded text to /content/Books/The Iliad by Homer/pg6130.txt
# Processing book 52 of 100: https://www.gutenberg.org/ebooks/47629
# Found book: Ang "Filibusterismo" (Karugtóng ng Noli Me Tangere) by José Rizal
# Downloaded text to /content/Books/Ang Filibusterismo (Karugtóng ng Noli Me Tangere) by José Rizal/pg47629.txt
# Processing book 53 of 100: https://www.gutenberg.org/ebooks/768
# Found book: Wuthering Heights by Emily Brontë
# Downloaded text to /content/Books/Wuthering Heights by Emily Brontë/pg768.txt
# Processing book 54 of 100: https://www.gutenberg.org/ebooks/4300
# Found book: Ulysses by James Joyce
# Downloaded text to /content/Books/Ulysses by James Joyce/pg4300.txt
# Processing book 55 of 100: https://www.gutenberg.org/ebooks/4363
# Found book: Beyond Good and Evil by Friedrich Wilhelm Nietzsche
# Downloaded text to /content/Books/Beyond Good and Evil by Friedrich Wilhelm Nietzsche/pg4363.txt
# Processing book 56 of 100: https://www.gutenberg.org/ebooks/2591
# Found book: Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm
# Downloaded text to /content/Books/Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm/pg2591.txt
# Processing book 57 of 100: https://www.gutenberg.org/ebooks/205
# Found book: Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau
# Downloaded text to /content/Books/Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau/pg205.txt
# Processing book 58 of 100: https://www.gutenberg.org/ebooks/1497
# Found book: The Republic by Plato
# Downloaded text to /content/Books/The Republic by Plato/pg1497.txt
# Processing book 59 of 100: https://www.gutenberg.org/ebooks/16328
# Found book: Beowulf: An Anglo-Saxon Epic Poem by J. Lesslie Hall
# Downloaded text to /content/Books/Beowulf An Anglo-Saxon Epic Poem by J. Lesslie Hall/pg16328.txt
# Processing book 60 of 100: https://www.gutenberg.org/ebooks/46
# Found book: A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens
# Downloaded text to /content/Books/A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens/pg46.txt
# Processing book 61 of 100: https://www.gutenberg.org/ebooks/10676
# Found book: The Reign of Greed by José Rizal
# Downloaded text to /content/Books/The Reign of Greed by José Rizal/pg10676.txt
# Processing book 62 of 100: https://www.gutenberg.org/ebooks/16119
# Found book: Doctrina Christiana by Edwin Wolf
# Downloaded text to /content/Books/Doctrina Christiana by Edwin Wolf/pg16119.txt
# Processing book 63 of 100: https://www.gutenberg.org/ebooks/74
# Found book: The Adventures of Tom Sawyer, Complete by Mark Twain
# Downloaded text to /content/Books/The Adventures of Tom Sawyer, Complete by Mark Twain/pg74.txt
# Processing book 64 of 100: https://www.gutenberg.org/ebooks/5740
# Found book: Tractatus Logico-Philosophicus by Ludwig Wittgenstein
# Could not find Plain Text UTF-8 link for Tractatus Logico-Philosophicus by Ludwig Wittgenstein
# Processing book 65 of 100: https://www.gutenberg.org/ebooks/45
# Found book: Anne of Green Gables by L. M. Montgomery
# Downloaded text to /content/Books/Anne of Green Gables by L. M. Montgomery/pg45.txt
# Processing book 66 of 100: https://www.gutenberg.org/ebooks/23
# Found book: Narrative of the Life of Frederick Douglass, an American Slave by Douglass
# Downloaded text to /content/Books/Narrative of the Life of Frederick Douglass, an American Slave by Douglass/pg23.txt
# Processing book 67 of 100: https://www.gutenberg.org/ebooks/25558
# Found book: 呻吟語 by Kun Lü
# Downloaded text to /content/Books/呻吟語 by Kun Lü/pg25558.txt
# Processing book 68 of 100: https://www.gutenberg.org/ebooks/3296
# Found book: The Confessions of St. Augustine by Bishop of Hippo Saint Augustine
# Downloaded text to /content/Books/The Confessions of St. Augustine by Bishop of Hippo Saint Augustine/pg3296.txt
# Processing book 69 of 100: https://www.gutenberg.org/ebooks/2814
# Found book: Dubliners by James Joyce
# Downloaded text to /content/Books/Dubliners by James Joyce/pg2814.txt
# Processing book 70 of 100: https://www.gutenberg.org/ebooks/55
# Found book: The Wonderful Wizard of Oz by L. Frank Baum
# Downloaded text to /content/Books/The Wonderful Wizard of Oz by L. Frank Baum/pg55.txt
# Processing book 71 of 100: https://www.gutenberg.org/ebooks/135
# Found book: Les Misérables by Victor Hugo
# Downloaded text to /content/Books/Les Misérables by Victor Hugo/pg135.txt
# Processing book 72 of 100: https://www.gutenberg.org/ebooks/36034
# Found book: White Nights and Other Stories by Fyodor Dostoyevsky
# Downloaded text to /content/Books/White Nights and Other Stories by Fyodor Dostoyevsky/pg36034.txt
# Processing book 73 of 100: https://www.gutenberg.org/ebooks/8800
# Found book: The divine comedy by Dante Alighieri
# Downloaded text to /content/Books/The divine comedy by Dante Alighieri/pg8800.txt
# Processing book 74 of 100: https://www.gutenberg.org/ebooks/15399
# Found book: The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa,…
# Downloaded text to /content/Books/The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa,…/pg15399.txt
# Processing book 75 of 100: https://www.gutenberg.org/ebooks/34901
# Found book: On Liberty by John Stuart Mill
# Downloaded text to /content/Books/On Liberty by John Stuart Mill/pg34901.txt
# Processing book 76 of 100: https://www.gutenberg.org/ebooks/30254
# Found book: The Romance of Lust: A classic Victorian erotic novel by Anonymous
# Downloaded text to /content/Books/The Romance of Lust A classic Victorian erotic novel by Anonymous/pg30254.txt
# Processing book 77 of 100: https://www.gutenberg.org/ebooks/1251
# Found book: Le Morte d'Arthur: Volume 1 by Sir Thomas Malory
# Downloaded text to /content/Books/Le Morte d'Arthur Volume 1 by Sir Thomas Malory/pg1251.txt
# Processing book 78 of 100: https://www.gutenberg.org/ebooks/132
# Found book: The Art of War by active 6th century B.C. Sunzi
# Downloaded text to /content/Books/The Art of War by active 6th century B.C. Sunzi/pg132.txt
# Processing book 79 of 100: https://www.gutenberg.org/ebooks/10007
# Found book: Carmilla by Joseph Sheridan Le Fanu
# Downloaded text to /content/Books/Carmilla by Joseph Sheridan Le Fanu/pg10007.txt
# Processing book 80 of 100: https://www.gutenberg.org/ebooks/15845
# Found book: Florante at Laura by Francisco Balagtas
# Downloaded text to /content/Books/Florante at Laura by Francisco Balagtas/pg15845.txt
# Processing book 81 of 100: https://www.gutenberg.org/ebooks/41
# Found book: The Legend of Sleepy Hollow by Washington Irving
# Downloaded text to /content/Books/The Legend of Sleepy Hollow by Washington Irving/pg41.txt
# Processing book 82 of 100: https://www.gutenberg.org/ebooks/7142
# Found book: The History of the Peloponnesian War by Thucydides
# Downloaded text to /content/Books/The History of the Peloponnesian War by Thucydides/pg7142.txt
# Processing book 83 of 100: https://www.gutenberg.org/ebooks/514
# Found book: Little Women by Louisa May Alcott
# Downloaded text to /content/Books/Little Women by Louisa May Alcott/pg514.txt
# Processing book 84 of 100: https://www.gutenberg.org/ebooks/2148
# Found book: The Works of Edgar Allan Poe — Volume 2 by Edgar Allan Poe
# Downloaded text to /content/Books/The Works of Edgar Allan Poe — Volume 2 by Edgar Allan Poe/pg2148.txt
# Processing book 85 of 100: https://www.gutenberg.org/ebooks/244
# Found book: A Study in Scarlet by Arthur Conan Doyle
# Downloaded text to /content/Books/A Study in Scarlet by Arthur Conan Doyle/pg244.txt
# Processing book 86 of 100: https://www.gutenberg.org/ebooks/996
# Found book: Don Quixote by Miguel de Cervantes Saavedra
# Downloaded text to /content/Books/Don Quixote by Miguel de Cervantes Saavedra/pg996.txt
# Processing book 87 of 100: https://www.gutenberg.org/ebooks/31552
# Found book: Novo dicionário da língua portuguesa by Cândido de Figueiredo
# Downloaded text to /content/Books/Novo dicionário da língua portuguesa by Cândido de Figueiredo/pg31552.txt
# Processing book 88 of 100: https://www.gutenberg.org/ebooks/15272
# Found book: Spenser's The Faerie Queene, Book I by Edmund Spenser
# Downloaded text to /content/Books/Spenser's The Faerie Queene, Book I by Edmund Spenser/pg15272.txt
# Processing book 89 of 100: https://www.gutenberg.org/ebooks/10623
# Found book: Plays by Susan Glaspell
# Downloaded text to /content/Books/Plays by Susan Glaspell/pg10623.txt
# Processing book 90 of 100: https://www.gutenberg.org/ebooks/45502
# Found book: How the Other Half Lives: Studies Among the Tenements of New York by Jacob A. Riis
# Downloaded text to /content/Books/How the Other Half Lives Studies Among the Tenements of New York by Jacob A. Riis/pg45502.txt
# Processing book 91 of 100: https://www.gutenberg.org/ebooks/2680
# Found book: Meditations by Emperor of Rome Marcus Aurelius
# Downloaded text to /content/Books/Meditations by Emperor of Rome Marcus Aurelius/pg2680.txt
# Processing book 92 of 100: https://www.gutenberg.org/ebooks/779
# Found book: The Tragical History of Doctor Faustus by Christopher Marlowe
# Downloaded text to /content/Books/The Tragical History of Doctor Faustus by Christopher Marlowe/pg779.txt
# Processing book 93 of 100: https://www.gutenberg.org/ebooks/36
# Found book: The War of the Worlds by H. G. Wells
# Downloaded text to /content/Books/The War of the Worlds by H. G. Wells/pg36.txt
# Processing book 94 of 100: https://www.gutenberg.org/ebooks/158
# Found book: Emma by Jane Austen
# Downloaded text to /content/Books/Emma by Jane Austen/pg158.txt
# Processing book 95 of 100: https://www.gutenberg.org/ebooks/42324
# Found book: Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley
# Downloaded text to /content/Books/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley/pg42324.txt
# Processing book 96 of 100: https://www.gutenberg.org/ebooks/19942
# Found book: Candide by Voltaire
# Downloaded text to /content/Books/Candide by Voltaire/pg19942.txt
# Processing book 97 of 100: https://www.gutenberg.org/ebooks/730
# Found book: Oliver Twist by Charles Dickens
# Downloaded text to /content/Books/Oliver Twist by Charles Dickens/pg730.txt
# Processing book 98 of 100: https://www.gutenberg.org/ebooks/1399
# Found book: Anna Karenina by graf Leo Tolstoy
# Downloaded text to /content/Books/Anna Karenina by graf Leo Tolstoy/pg1399.txt
# Processing book 99 of 100: https://www.gutenberg.org/ebooks/27827
# Found book: The Kama Sutra of Vatsyayana by Vatsyayana
# Downloaded text to /content/Books/The Kama Sutra of Vatsyayana by Vatsyayana/pg27827.txt
# Processing book 100 of 100: https://www.gutenberg.org/ebooks/5827
# Found book: The Problems of Philosophy by Bertrand Russell
# Downloaded text to /content/Books/The Problems of Philosophy by Bertrand Russell/pg5827.txt
# CSV file created at /content/gutenberg_top100.csv
# Downloaded 99 out of 100 books

# %%
import os
import re
import csv
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Create necessary directory
os.makedirs('/content/Other Books', exist_ok=True)

# Function to sanitize filenames (remove characters not allowed in directory names)
def sanitize_filename(name):
    return re.sub(r'[\\/*?:"<>|]', "", name)

# Function to extract book ID from URL
def extract_book_id(url):
    match = re.search(r'/ebooks/(\d+)', url)
    if match:
        return match.group(1)
    return None

# Base URL
base_url = "https://www.gutenberg.org"

# URL of the last 30 days page
recent_books_url = f"{base_url}/browse/recent/last30"

# List to store all the book data
books_data = []

# Get the recent books page
print("Accessing Recent Books page...")
response = requests.get(recent_books_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all links that start with /ebooks/ followed by a number
book_links = []
for link in soup.find_all('a', href=re.compile(r'^/ebooks/\d+')):
    book_url = urljoin(base_url, link.get('href'))
    # Extract the title from the link text
    title = link.text.strip()
    # Extract the book ID from the URL
    book_id = extract_book_id(book_url)

    if book_id and title:
        book_links.append({
            'url': book_url,
            'title': title,
            'id': book_id
        })

print(f"Found {len(book_links)} book links")

# Process each book
for i, book in enumerate(book_links, 1):
    try:
        print(f"Processing book {i} of {len(book_links)}: {book['title']} (ID: {book['id']})")

        # Get the book page
        response = requests.get(book['url'])
        if response.status_code != 200:
            print(f"Failed to access {book['url']}")
            continue

        book_soup = BeautifulSoup(response.text, 'html.parser')

        # Look for the Plain Text UTF-8 link
        plain_text_link = None
        for link in book_soup.find_all('a', {'type': 'text/plain; charset=us-ascii', 'class': 'link'}):
            if "Plain Text UTF-8" in link.text:
                plain_text_link = urljoin(base_url, link.get('href'))
                break

        if not plain_text_link:
            print(f"Could not find Plain Text UTF-8 link for {book['title']}")
            continue

        # Get the actual text file
        response = requests.get(plain_text_link, allow_redirects=True)
        if response.status_code != 200:
            print(f"Failed to access Plain Text UTF-8 file for {book['title']}")
            continue

        # Get the final URL after redirects
        final_url = response.url

        # Extract the filename from the final URL
        filename = os.path.basename(final_url)

        # If the filename doesn't end with .txt, add it
        if not filename.endswith('.txt'):
            filename = f"{filename}.txt"

        # Create sanitized folder name
        folder_name = sanitize_filename(book['title'])
        folder_path = os.path.join('/content/Other Books', folder_name)
        os.makedirs(folder_path, exist_ok=True)

        # Store the actual text content
        destination = os.path.join(folder_path, filename)
        with open(destination, 'wb') as f:
            f.write(response.content)
        print(f"Downloaded text to {destination}")

        # Store the book information
        books_data.append({
            'Title': book['title'],
            'Number': book['id'],
            'Filename': filename
        })

        # Add a small delay to avoid hammering the server
        time.sleep(1)

    except Exception as e:
        print(f"Error processing {book['url']}: {str(e)}")

# Write the CSV file
csv_path = '/content/gutenberg_recent_books.csv'
with open(csv_path, 'w', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Title', 'Number', 'Filename']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    for book in books_data:
        writer.writerow(book)

print(f"CSV file created at {csv_path}")
print(f"Downloaded {len(books_data)} out of {len(book_links)} books")
# Out:
# Accessing Recent Books page...
# Found 562 book links
# Processing book 1 of 562: Jungen :  Vierzehn Geschichten von kleinen ganzen Kerlen (ID: 75541)
# Downloaded text to /content/Other Books/Jungen   Vierzehn Geschichten von kleinen ganzen Kerlen/pg75541.txt
# Processing book 2 of 562: An illustrated commentary on the Gospel according to St. John (ID: 75543)
# Downloaded text to /content/Other Books/An illustrated commentary on the Gospel according to St. John/pg75543.txt
# Processing book 3 of 562: Das Cistercienserstift Heiligenkreuz in Niederösterreich (ID: 75371)
# Downloaded text to /content/Other Books/Das Cistercienserstift Heiligenkreuz in Niederösterreich/pg75371.txt
# Processing book 4 of 562: Le Père Lebonnard :  Comédie en 4 actes, en vers, reprise à la Comédie Française le 4 août 1904 (ID: 75459)
# Downloaded text to /content/Other Books/Le Père Lebonnard   Comédie en 4 actes, en vers, reprise à la Comédie Française le 4 août 1904/pg75459.txt
# Processing book 5 of 562: Jessie :  or, trying to be somebody (ID: 75385)
# Downloaded text to /content/Other Books/Jessie   or, trying to be somebody/pg75385.txt
# Processing book 6 of 562: The Errand Boy; Or, How Phil Brent Won Success (ID: 462)
# Downloaded text to /content/Other Books/The Errand Boy; Or, How Phil Brent Won Success/pg462.txt
# Processing book 7 of 562: The crime at Black Dudley (ID: 75359)
# Downloaded text to /content/Other Books/The crime at Black Dudley/pg75359.txt
# Processing book 8 of 562: Electric railways (ID: 75289)
# Downloaded text to /content/Other Books/Electric railways/pg75289.txt
# Processing book 9 of 562: The Mayflower and Her Log; July 15, 1620-May 6, 1621 — Complete (ID: 4107)
# Downloaded text to /content/Other Books/The Mayflower and Her Log; July 15, 1620-May 6, 1621 — Complete/pg4107.txt
# Processing book 10 of 562: Jungen :  Vierzehn Geschichten von kleinen ganzen Kerlen (ID: 75541)
# Downloaded text to /content/Other Books/Jungen   Vierzehn Geschichten von kleinen ganzen Kerlen/pg75541.txt
# Processing book 11 of 562: Do you believe in fairies? (ID: 75356)
# Downloaded text to /content/Other Books/Do you believe in fairies/pg75356.txt
# Processing book 12 of 562: Takáts Sándor Szalai Barkóczy Krisztina 1671-1724 czímű könyvének ismertetése (ID: 19040)
# Downloaded text to /content/Other Books/Takáts Sándor Szalai Barkóczy Krisztina 1671-1724 czímű könyvének ismertetése/pg19040.txt
# Processing book 13 of 562: A day in Mary Carrow's school (ID: 75343)
# Downloaded text to /content/Other Books/A day in Mary Carrow's school/pg75343.txt
# Processing book 14 of 562: King Winter (ID: 17764)
# Downloaded text to /content/Other Books/King Winter/pg17764.txt
# Processing book 15 of 562: Wreck of the "London." (ID: 75381)
# Downloaded text to /content/Other Books/Wreck of the London./pg75381.txt
# Processing book 16 of 562: Dolores parka! :  Andalusialainen kertomus (ID: 75495)
# Downloaded text to /content/Other Books/Dolores parka!   Andalusialainen kertomus/pg75495.txt
# Processing book 17 of 562: Le mal d'aimer (ID: 75447)
# Downloaded text to /content/Other Books/Le mal d'aimer/pg75447.txt
# Processing book 18 of 562: Vingt jours en Tunisie (ID: 75517)
# Downloaded text to /content/Other Books/Vingt jours en Tunisie/pg75517.txt
# Processing book 19 of 562: Brazil, the land of rubber :  At the third international rubber and allied trades exhibition, New York, 1912 (ID: 75473)
# Downloaded text to /content/Other Books/Brazil, the land of rubber   At the third international rubber and allied trades exhibition, New York, 1912/pg75473.txt
# Processing book 20 of 562: Brazil, the land of rubber :  At the third international rubber and allied trades exhibition, New York, 1912 (ID: 75473)
# Downloaded text to /content/Other Books/Brazil, the land of rubber   At the third international rubber and allied trades exhibition, New York, 1912/pg75473.txt
# Processing book 21 of 562: Edaville Railroad :  The Cranberry Belt (ID: 75376)
# Downloaded text to /content/Other Books/Edaville Railroad   The Cranberry Belt/pg75376.txt
# Processing book 22 of 562: The coins of India (ID: 75542)
# Downloaded text to /content/Other Books/The coins of India/pg75542.txt
# Processing book 23 of 562: Greek wayfarers, and other poems (ID: 75533)
# Downloaded text to /content/Other Books/Greek wayfarers, and other poems/pg75533.txt
# Processing book 24 of 562: Gustaf Fröding (ID: 75504)
# Downloaded text to /content/Other Books/Gustaf Fröding/pg75504.txt
# Processing book 25 of 562: Poems (ID: 75489)
# Downloaded text to /content/Other Books/Poems/pg75489.txt
# Processing book 26 of 562: The basket maker (ID: 75361)
# Downloaded text to /content/Other Books/The basket maker/pg75361.txt
# Processing book 27 of 562: "I was there" with the Yanks on the western front, 1917-1919 (ID: 15937)
# Downloaded text to /content/Other Books/I was there with the Yanks on the western front, 1917-1919/pg15937.txt
# Processing book 28 of 562: The achievements of Luther Trant (ID: 75523)
# Downloaded text to /content/Other Books/The achievements of Luther Trant/pg75523.txt
# Processing book 29 of 562: Cousin Pons (ID: 1856)
# Downloaded text to /content/Other Books/Cousin Pons/pg1856.txt
# Processing book 30 of 562: A Distinguished Provincial at Paris (ID: 1559)
# Downloaded text to /content/Other Books/A Distinguished Provincial at Paris/pg1559.txt
# Processing book 31 of 562: Eve and David (ID: 1639)
# Downloaded text to /content/Other Books/Eve and David/pg1639.txt
# Processing book 32 of 562: Two Poets (ID: 1443)
# Downloaded text to /content/Other Books/Two Poets/pg1443.txt
# Processing book 33 of 562: The Unknown Masterpiece1845 (ID: 23060)
# Downloaded text to /content/Other Books/The Unknown Masterpiece1845/pg23060.txt
# Processing book 34 of 562: Isänmaattomat :  Romaani (ID: 75336)
# Downloaded text to /content/Other Books/Isänmaattomat   Romaani/pg75336.txt
# Processing book 35 of 562: Eighteen Hundred and Eleven (ID: 14100)
# Downloaded text to /content/Other Books/Eighteen Hundred and Eleven/pg14100.txt
# Processing book 36 of 562: Blackbeard; Or, The Pirate of Roanoke. (ID: 17863)
# Downloaded text to /content/Other Books/Blackbeard; Or, The Pirate of Roanoke./pg17863.txt
# Processing book 37 of 562: Pieter Bruegel the Elder :  A study of his paintings (ID: 75540)
# Downloaded text to /content/Other Books/Pieter Bruegel the Elder   A study of his paintings/pg75540.txt
# Processing book 38 of 562: Bog-land studies (ID: 75538)
# Downloaded text to /content/Other Books/Bog-land studies/pg75538.txt
# Processing book 39 of 562: A creel of Irish stories (ID: 75587)
# Downloaded text to /content/Other Books/A creel of Irish stories/pg75587.txt
# Processing book 40 of 562: The tongues of toil, and other poems (ID: 13322)
# Downloaded text to /content/Other Books/The tongues of toil, and other poems/pg13322.txt
# Processing book 41 of 562: Deeds of heroism and bravery :  The book of heroes and personal daring (ID: 75487)
# Downloaded text to /content/Other Books/Deeds of heroism and bravery   The book of heroes and personal daring/pg75487.txt
# Processing book 42 of 562: The Nile quest :  a record of the exploration of the Nile and its basin (ID: 75534)
# Downloaded text to /content/Other Books/The Nile quest   a record of the exploration of the Nile and its basin/pg75534.txt
# Processing book 43 of 562: David goes to Greenland (ID: 75370)
# Downloaded text to /content/Other Books/David goes to Greenland/pg75370.txt
# Processing book 44 of 562: Légendes canaques (ID: 75549)
# Downloaded text to /content/Other Books/Légendes canaques/pg75549.txt
# Processing book 45 of 562: "I was there" with the Yanks on the western front, 1917-1919 (ID: 15937)
# Downloaded text to /content/Other Books/I was there with the Yanks on the western front, 1917-1919/pg15937.txt
# Processing book 46 of 562: The Life and Adventures of Santa Claus (ID: 520)
# Downloaded text to /content/Other Books/The Life and Adventures of Santa Claus/pg520.txt
# Processing book 47 of 562: The Dancing Faun (ID: 75492)
# Downloaded text to /content/Other Books/The Dancing Faun/pg75492.txt
# 1908 (ID: 24895)
# 1908/pg24895.txt
# Processing book 49 of 562: Legends, Tales and Poems (ID: 10814)
# Downloaded text to /content/Other Books/Legends, Tales and Poems/pg10814.txt
# Processing book 50 of 562: Legends, Tales and Poems (ID: 10814)
# Downloaded text to /content/Other Books/Legends, Tales and Poems/pg10814.txt
# Processing book 51 of 562: Our search for a wilderness :  An account of two ornithological expeditions to Venezuela and to British Guiana (ID: 75453)
# Downloaded text to /content/Other Books/Our search for a wilderness   An account of two ornithological expeditions to Venezuela and to British Guiana/pg75453.txt
# Processing book 52 of 562: The dreadful dragon of Hay Hill (ID: 75341)
# Downloaded text to /content/Other Books/The dreadful dragon of Hay Hill/pg75341.txt
# Processing book 53 of 562: Portuguese literature (ID: 75425)
# Downloaded text to /content/Other Books/Portuguese literature/pg75425.txt
# Processing book 54 of 562: Cautionary Tales for Children (ID: 27424)
# Downloaded text to /content/Other Books/Cautionary Tales for Children/pg27424.txt
# Processing book 55 of 562: The Pyrenees (ID: 75369)
# Downloaded text to /content/Other Books/The Pyrenees/pg75369.txt
# Processing book 56 of 562: La Cour d'Assises, ses pompes et ses œuvres (ID: 75502)
# Downloaded text to /content/Other Books/La Cour d'Assises, ses pompes et ses œuvres/pg75502.txt
# Processing book 57 of 562: Jungen :  Vierzehn Geschichten von kleinen ganzen Kerlen (ID: 75541)
# Downloaded text to /content/Other Books/Jungen   Vierzehn Geschichten von kleinen ganzen Kerlen/pg75541.txt
# Processing book 58 of 562: The poisoned chocolates case (ID: 75476)
# Downloaded text to /content/Other Books/The poisoned chocolates case/pg75476.txt
# Processing book 59 of 562: The sirens :  An ode (ID: 75422)
# Downloaded text to /content/Other Books/The sirens   An ode/pg75422.txt
# Processing book 60 of 562: Sweated industry and the minimum wage (ID: 75467)
# Downloaded text to /content/Other Books/Sweated industry and the minimum wage/pg75467.txt
# Processing book 61 of 562: John Silence, Physician Extraordinary (ID: 49222)
# Downloaded text to /content/Other Books/John Silence, Physician Extraordinary/pg49222.txt
# Processing book 62 of 562: Dimple Dallas :  The further fortunes of a sweet little maid (ID: 75380)
# Downloaded text to /content/Other Books/Dimple Dallas   The further fortunes of a sweet little maid/pg75380.txt
# Processing book 63 of 562: Lord Lister No. 0125: Een vreemde geschiedenis (ID: 75575)
# Downloaded text to /content/Other Books/Lord Lister No. 0125 Een vreemde geschiedenis/pg75575.txt
# Processing book 64 of 562: The belle of a season (ID: 75596)
# Downloaded text to /content/Other Books/The belle of a season/pg75596.txt
# Processing book 65 of 562: Rambles in Waltham Forest :  a stranger's contribution to the triennial sale for the benefit of the Wanstead Lying-in Charity (ID: 75349)
# Downloaded text to /content/Other Books/Rambles in Waltham Forest   a stranger's contribution to the triennial sale for the benefit of the Wanstead Lying-in Charity/pg75349.txt
# Processing book 66 of 562: Der krasse Fuchs :  Roman (ID: 75450)
# Downloaded text to /content/Other Books/Der krasse Fuchs   Roman/pg75450.txt
# Processing book 67 of 562: Das Land unserer Liebe :  Roman (ID: 75470)
# Downloaded text to /content/Other Books/Das Land unserer Liebe   Roman/pg75470.txt
# Processing book 68 of 562: Sommerleutnants :  Die Geschichte einer achtwöchigen Übung (ID: 75388)
# Downloaded text to /content/Other Books/Sommerleutnants   Die Geschichte einer achtwöchigen Übung/pg75388.txt
# Processing book 69 of 562: The secret commonwealth of elves, fauns & fairies (ID: 75485)
# Downloaded text to /content/Other Books/The secret commonwealth of elves, fauns & fairies/pg75485.txt
# Processing book 70 of 562: Histoire amoureuse des Gaules; suivie des Romans historico-satiriques du XVIIe siècle, Tome II (ID: 28789)
# Downloaded text to /content/Other Books/Histoire amoureuse des Gaules; suivie des Romans historico-satiriques du XVIIe siècle, Tome II/pg28789.txt
# Processing book 71 of 562: Wild oats (ID: 75552)
# Downloaded text to /content/Other Books/Wild oats/pg75552.txt
# Processing book 72 of 562: Vanhankansan tapoja ja taikoja :  y.m. sivistyshistoriallisia pikkutietoja Keski-Hämeestä 1800-luvulta (ID: 75536)
# Downloaded text to /content/Other Books/Vanhankansan tapoja ja taikoja   y.m. sivistyshistoriallisia pikkutietoja Keski-Hämeestä 1800-luvulta/pg75536.txt
# Processing book 73 of 562: Needwood Forest (ID: 75378)
# Downloaded text to /content/Other Books/Needwood Forest/pg75378.txt
# Processing book 74 of 562: Life, the Interpreter (ID: 75508)
# Downloaded text to /content/Other Books/Life, the Interpreter/pg75508.txt
# Processing book 75 of 562: The Victim and The Worm (ID: 75526)
# Downloaded text to /content/Other Books/The Victim and The Worm/pg75526.txt
# Processing book 76 of 562: Deeds of heroism and bravery :  The book of heroes and personal daring (ID: 75487)
# Downloaded text to /content/Other Books/Deeds of heroism and bravery   The book of heroes and personal daring/pg75487.txt
# Processing book 77 of 562: Le spectre de M. Imberger (ID: 75483)
# Downloaded text to /content/Other Books/Le spectre de M. Imberger/pg75483.txt
# Processing book 78 of 562: Cow-Country (ID: 1723)
# Downloaded text to /content/Other Books/Cow-Country/pg1723.txt
# Processing book 79 of 562: Cavalry life in tent and field (ID: 75558)
# Downloaded text to /content/Other Books/Cavalry life in tent and field/pg75558.txt
# Processing book 80 of 562: Asphodel :  a novel (ID: 75506)
# Downloaded text to /content/Other Books/Asphodel   a novel/pg75506.txt
# Processing book 81 of 562: The fatal three, vol. I (ID: 75410)
# Downloaded text to /content/Other Books/The fatal three, vol. I/pg75410.txt
# Processing book 82 of 562: The fatal three, vol. II (ID: 75411)
# Downloaded text to /content/Other Books/The fatal three, vol. II/pg75411.txt
# Processing book 83 of 562: The fatal three, vol. III (ID: 75412)
# Downloaded text to /content/Other Books/The fatal three, vol. III/pg75412.txt
# Processing book 84 of 562: The story of Flamenca :  The first modern novel, arranged from the Provençal original of the Thirteenth Century by William Aspenwall Bradley (ID: 75417)
# Downloaded text to /content/Other Books/The story of Flamenca   The first modern novel, arranged from the Provençal original of the Thirteenth Century by William Aspenwall Bradley/pg75417.txt
# Processing book 85 of 562: Brazil, the land of rubber :  At the third international rubber and allied trades exhibition, New York, 1912 (ID: 75473)
# Downloaded text to /content/Other Books/Brazil, the land of rubber   At the third international rubber and allied trades exhibition, New York, 1912/pg75473.txt
# Processing book 86 of 562: Brazil, the land of rubber :  At the third international rubber and allied trades exhibition, New York, 1912 (ID: 75473)
# Downloaded text to /content/Other Books/Brazil, the land of rubber   At the third international rubber and allied trades exhibition, New York, 1912/pg75473.txt
# Processing book 87 of 562: Destiny (ID: 75340)
# Downloaded text to /content/Other Books/Destiny/pg75340.txt
# Processing book 88 of 562: Le Sud-Oranais: études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901 (ID: 75454)
# Downloaded text to /content/Other Books/Le Sud-Oranais études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901/pg75454.txt
# Processing book 89 of 562: The case of Miss Elliott (ID: 75461)
# Downloaded text to /content/Other Books/The case of Miss Elliott/pg75461.txt
# Processing book 90 of 562: The star jewels, and other wonders (ID: 75499)
# Downloaded text to /content/Other Books/The star jewels, and other wonders/pg75499.txt
# Processing book 91 of 562: The coins of India (ID: 75542)
# Downloaded text to /content/Other Books/The coins of India/pg75542.txt
# Processing book 92 of 562: Christina and the boys (ID: 75332)
# Downloaded text to /content/Other Books/Christina and the boys/pg75332.txt
# Processing book 93 of 562: The star jewels, and other wonders (ID: 75499)
# Downloaded text to /content/Other Books/The star jewels, and other wonders/pg75499.txt
# Processing book 94 of 562: Pieter Bruegel the Elder :  A study of his paintings (ID: 75540)
# Downloaded text to /content/Other Books/Pieter Bruegel the Elder   A study of his paintings/pg75540.txt
# Processing book 95 of 562: Cautionary Tales for Children (ID: 27424)
# Downloaded text to /content/Other Books/Cautionary Tales for Children/pg27424.txt
# Processing book 96 of 562: Auf alten Wegen :  Novellen (ID: 75592)
# Downloaded text to /content/Other Books/Auf alten Wegen   Novellen/pg75592.txt
# Processing book 97 of 562: Songs and lyrics of Robert Burns (ID: 75462)
# Downloaded text to /content/Other Books/Songs and lyrics of Robert Burns/pg75462.txt
# Processing book 98 of 562: The Book of the Thousand Nights and a Night — Volume 11 [Supplement] (ID: 3445)
# Downloaded text to /content/Other Books/The Book of the Thousand Nights and a Night — Volume 11 [Supplement]/pg3445.txt
# Processing book 99 of 562: The Book of the Thousand Nights and a Night — Volume 14 (ID: 3448)
# Downloaded text to /content/Other Books/The Book of the Thousand Nights and a Night — Volume 14/pg3448.txt
# Processing book 100 of 562: The Book of the Thousand Nights and a Night — Volume 16 (ID: 3450)
# Downloaded text to /content/Other Books/The Book of the Thousand Nights and a Night — Volume 16/pg3450.txt
# Processing book 101 of 562: Histoire amoureuse des Gaules; suivie des Romans historico-satiriques du XVIIe siècle, Tome II (ID: 28789)
# Downloaded text to /content/Other Books/Histoire amoureuse des Gaules; suivie des Romans historico-satiriques du XVIIe siècle, Tome II/pg28789.txt
# Processing book 102 of 562: A Journey Through France in War Time (ID: 20464)
# Downloaded text to /content/Other Books/A Journey Through France in War Time/pg20464.txt
# Processing book 103 of 562: Address, delivered in Craigie Hall, Edinburgh, February 24th, 1871 (ID: 75348)
# Downloaded text to /content/Other Books/Address, delivered in Craigie Hall, Edinburgh, February 24th, 1871/pg75348.txt
# Processing book 104 of 562: The education and employment of women (ID: 75350)
# Downloaded text to /content/Other Books/The education and employment of women/pg75350.txt
# Processing book 105 of 562: Personal Recollections of Pardee Butler (ID: 12973)
# Downloaded text to /content/Other Books/Personal Recollections of Pardee Butler/pg12973.txt
# Processing book 106 of 562: Little Metacomet :  or, The Indian playmate (ID: 75556)
# Downloaded text to /content/Other Books/Little Metacomet   or, The Indian playmate/pg75556.txt
# Processing book 107 of 562: Don Juan (ID: 21700)
# Downloaded text to /content/Other Books/Don Juan/pg21700.txt
# Processing book 108 of 562: Behind the prison bars :  A reminder of our duties toward those who have been so unfortunate as to be cast into prison (ID: 75420)
# Downloaded text to /content/Other Books/Behind the prison bars   A reminder of our duties toward those who have been so unfortunate as to be cast into prison/pg75420.txt
# Processing book 109 of 562: Dolores parka! :  Andalusialainen kertomus (ID: 75495)
# Downloaded text to /content/Other Books/Dolores parka!   Andalusialainen kertomus/pg75495.txt
# Processing book 110 of 562: Commentarii de Bello Gallico, Libri V-VIII (ID: 18837)
# Downloaded text to /content/Other Books/Commentarii de Bello Gallico, Libri V-VIII/pg18837.txt
# Processing book 111 of 562: Travels through Central Africa to Timbuctoo; and across the Great Desert, to Morocco, performed in the years 1824-1828, Vol. 1 (of 2) (ID: 69847)
# Downloaded text to /content/Other Books/Travels through Central Africa to Timbuctoo; and across the Great Desert, to Morocco, performed in the years 1824-1828, Vol. 1 (of 2)/pg69847.txt
# Processing book 112 of 562: Suru-Runot Suomalaiset (ID: 75444)
# Downloaded text to /content/Other Books/Suru-Runot Suomalaiset/pg75444.txt
# Processing book 113 of 562: Vähäinen cocous suomalaisista runoista :  Turusa 1755 (ID: 75429)
# Downloaded text to /content/Other Books/Vähäinen cocous suomalaisista runoista   Turusa 1755/pg75429.txt
# Processing book 114 of 562: Essays towards the history of painting (ID: 75528)
# Downloaded text to /content/Other Books/Essays towards the history of painting/pg75528.txt
# Processing book 115 of 562: Le Sud-Oranais: études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901 (ID: 75454)
# Downloaded text to /content/Other Books/Le Sud-Oranais études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901/pg75454.txt
# Processing book 116 of 562: Phil Purcel, The Pig-Driver; The Geography Of An Irish Oath; The Lianhan SheeTraits And Stories Of The Irish Peasantry, The Works ofWilliam Carleton, Volume Three (ID: 16015)
# Downloaded text to /content/Other Books/Phil Purcel, The Pig-Driver; The Geography Of An Irish Oath; The Lianhan SheeTraits And Stories Of The Irish Peasantry, The Works ofWilliam Carleton, Volume Three/pg16015.txt
# Processing book 117 of 562: The Problem of Truth (ID: 47658)
# Downloaded text to /content/Other Books/The Problem of Truth/pg47658.txt
# Processing book 118 of 562: Carolyn of the sunny heart (ID: 75509)
# Downloaded text to /content/Other Books/Carolyn of the sunny heart/pg75509.txt
# Processing book 119 of 562: My Ántonia (ID: 19810)
# Downloaded text to /content/Other Books/My Ántonia/pg19810.txt
# Processing book 120 of 562: Repertory of The Comedie Humaine, Complete, A — Z (ID: 17635)
# Downloaded text to /content/Other Books/Repertory of The Comedie Humaine, Complete, A — Z/pg17635.txt
# Processing book 121 of 562: The belle of a season (ID: 75596)
# Downloaded text to /content/Other Books/The belle of a season/pg75596.txt
# Processing book 122 of 562: Chambers's Edinburgh Journal, No. 425Volume 17, New Series, February 21, 1852 (ID: 16924)
# Downloaded text to /content/Other Books/Chambers's Edinburgh Journal, No. 425Volume 17, New Series, February 21, 1852/pg16924.txt
# Processing book 123 of 562: Chambers's Edinburgh Journal, No. 425Volume 17, New Series, February 21, 1852 (ID: 16924)
# Downloaded text to /content/Other Books/Chambers's Edinburgh Journal, No. 425Volume 17, New Series, February 21, 1852/pg16924.txt
# Processing book 124 of 562: The Iliads of HomerTranslated according to the Greek (ID: 51355)
# Downloaded text to /content/Other Books/The Iliads of HomerTranslated according to the Greek/pg51355.txt
# Processing book 125 of 562: Deeds of heroism and bravery :  The book of heroes and personal daring (ID: 75487)
# Downloaded text to /content/Other Books/Deeds of heroism and bravery   The book of heroes and personal daring/pg75487.txt
# Processing book 126 of 562: Yntemoca yntlacamecayo, yn tlahtoque yn teteuhctin yn ompa tlaca ypan altepetl culhuacan yhuan nican tlahtoque teteuhctin yn ipan in tlaca huey altepetl mexico tenochtitlanOquitlallitiaque yn tlahtoque teteuhctin culhuacan (ID: 21802)
# Downloaded text to /content/Other Books/Yntemoca yntlacamecayo, yn tlahtoque yn teteuhctin yn ompa tlaca ypan altepetl culhuacan yhuan nican tlahtoque teteuhctin yn ipan in tlaca huey altepetl mexico tenochtitlanOquitlallitiaque yn tlahtoque teteuhctin culhuacan/pg21802.txt
# Processing book 127 of 562: L'avision de Christine (ID: 75554)
# Downloaded text to /content/Other Books/L'avision de Christine/pg75554.txt
# Processing book 128 of 562: Repertory of The Comedie Humaine, Complete, A — Z (ID: 17635)
# Downloaded text to /content/Other Books/Repertory of The Comedie Humaine, Complete, A — Z/pg17635.txt
# Processing book 129 of 562: Stories of Charlemagne and the twelve Peers of France :  from the old romances (ID: 75339)
# Downloaded text to /content/Other Books/Stories of Charlemagne and the twelve Peers of France   from the old romances/pg75339.txt
# Processing book 130 of 562: Richard Carvel — Complete (ID: 5373)
# Downloaded text to /content/Other Books/Richard Carvel — Complete/pg5373.txt
# Processing book 131 of 562: Claude Monet; les Nympheas (ID: 75353)
# Downloaded text to /content/Other Books/Claude Monet; les Nympheas/pg75353.txt
# Processing book 132 of 562: Aunt Anne, Vol. 1 (of 2) (ID: 75403)
# Downloaded text to /content/Other Books/Aunt Anne, Vol. 1 (of 2)/pg75403.txt
# Processing book 133 of 562: Aunt Anne, Vol. 2 (of 2) (ID: 75404)
# Downloaded text to /content/Other Books/Aunt Anne, Vol. 2 (of 2)/pg75404.txt
# Processing book 134 of 562: Pioneers of Evolution from Thales to HuxleyWith an Intermediate Chapter on the Causes of Arrest of the Movement (ID: 39526)
# Downloaded text to /content/Other Books/Pioneers of Evolution from Thales to HuxleyWith an Intermediate Chapter on the Causes of Arrest of the Movement/pg39526.txt
# Processing book 135 of 562: The crystal planetoids (ID: 75478)
# Downloaded text to /content/Other Books/The crystal planetoids/pg75478.txt
# Processing book 136 of 562: Giants in the earth (ID: 75491)
# Downloaded text to /content/Other Books/Giants in the earth/pg75491.txt
# Processing book 137 of 562: Tragedy at Ravensthorpe (ID: 75407)
# Downloaded text to /content/Other Books/Tragedy at Ravensthorpe/pg75407.txt
# Processing book 138 of 562: Chance: A Tale in Two Parts (ID: 1476)
# Downloaded text to /content/Other Books/Chance A Tale in Two Parts/pg1476.txt
# Processing book 139 of 562: Tales Of Hearsay (ID: 17732)
# Downloaded text to /content/Other Books/Tales Of Hearsay/pg17732.txt
# Processing book 140 of 562: Cap'n Jonah's fortune :  A story of Cape Cod (ID: 75584)
# Downloaded text to /content/Other Books/Cap'n Jonah's fortune   A story of Cape Cod/pg75584.txt
# Processing book 141 of 562: Les gràcies de l'Empordà (ID: 75521)
# Downloaded text to /content/Other Books/Les gràcies de l'Empordà/pg75521.txt
# Processing book 142 of 562: Le Sud-Oranais: études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901 (ID: 75454)
# Downloaded text to /content/Other Books/Le Sud-Oranais études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901/pg75454.txt
# Processing book 143 of 562: Da Sassari a Cagliari e viceversa :  guida-racconto (ID: 75510)
# Downloaded text to /content/Other Books/Da Sassari a Cagliari e viceversa   guida-racconto/pg75510.txt
# Processing book 144 of 562: Voittoisa nainen (ID: 75335)
# Downloaded text to /content/Other Books/Voittoisa nainen/pg75335.txt
# Processing book 145 of 562: Spectacle secrets (ID: 75415)
# Downloaded text to /content/Other Books/Spectacle secrets/pg75415.txt
# Processing book 146 of 562: My life and balloon experiences :  With a supplementary chapter on military ballooning (ID: 75423)
# Downloaded text to /content/Other Books/My life and balloon experiences   With a supplementary chapter on military ballooning/pg75423.txt
# Designed by Walter Crane (ID: 23479)
# Designed by Walter Crane/pg23479.txt
# Processing book 148 of 562: Electric railways (ID: 75289)
# Downloaded text to /content/Other Books/Electric railways/pg75289.txt
# Processing book 149 of 562: La morta :  Quadro dramátich (ID: 75579)
# Downloaded text to /content/Other Books/La morta   Quadro dramátich/pg75579.txt
# Processing book 150 of 562: The purple sickle murders (ID: 75488)
# Downloaded text to /content/Other Books/The purple sickle murders/pg75488.txt
# Processing book 151 of 562: Her own people (ID: 75402)
# Downloaded text to /content/Other Books/Her own people/pg75402.txt
# Designed by Walter Crane (ID: 23479)
# Designed by Walter Crane/pg23479.txt
# Processing book 153 of 562: Highland annals (ID: 75567)
# Downloaded text to /content/Other Books/Highland annals/pg75567.txt
# Processing book 154 of 562: A Visit From Saint Nicholas (ID: 17382)
# Downloaded text to /content/Other Books/A Visit From Saint Nicholas/pg17382.txt
# Processing book 155 of 562: Needwood Forest (ID: 75378)
# Downloaded text to /content/Other Books/Needwood Forest/pg75378.txt
# Processing book 156 of 562: Needwood Forest (ID: 75378)
# Downloaded text to /content/Other Books/Needwood Forest/pg75378.txt
# Processing book 157 of 562: A lyttel booke of nonsense (ID: 75511)
# Downloaded text to /content/Other Books/A lyttel booke of nonsense/pg75511.txt
# Processing book 158 of 562: The just steward (ID: 75518)
# Downloaded text to /content/Other Books/The just steward/pg75518.txt
# Processing book 159 of 562: The Haunted Man and the Ghost's Bargain (ID: 644)
# Downloaded text to /content/Other Books/The Haunted Man and the Ghost's Bargain/pg644.txt
# Processing book 160 of 562: Household words, no. 306, February 2, 1856 :  A weekly journal (ID: 75344)
# Downloaded text to /content/Other Books/Household words, no. 306, February 2, 1856   A weekly journal/pg75344.txt
# Processing book 161 of 562: The lazy detective (ID: 75493)
# Downloaded text to /content/Other Books/The lazy detective/pg75493.txt
# Processing book 162 of 562: Dorothy Dix—her book :  Every-day help for every-day people (ID: 75448)
# Downloaded text to /content/Other Books/Dorothy Dix—her book   Every-day help for every-day people/pg75448.txt
# Processing book 163 of 562: Arme Leute; Der Doppelgänger :  Zwei Romane (ID: 35339)
# Downloaded text to /content/Other Books/Arme Leute; Der Doppelgänger   Zwei Romane/pg35339.txt
# Processing book 164 of 562: Some old masters of Greek architecture (ID: 75561)
# Downloaded text to /content/Other Books/Some old masters of Greek architecture/pg75561.txt
# Processing book 165 of 562: Monsieur, Madame, and Bébé — Complete (ID: 3926)
# Downloaded text to /content/Other Books/Monsieur, Madame, and Bébé — Complete/pg3926.txt
# Processing book 166 of 562: A Little Rebel (ID: 16186)
# Downloaded text to /content/Other Books/A Little Rebel/pg16186.txt
# Processing book 167 of 562: Wurra-Wurra :  A legend of Saint Patrick at Tara (ID: 75537)
# Downloaded text to /content/Other Books/Wurra-Wurra   A legend of Saint Patrick at Tara/pg75537.txt
# Processing book 168 of 562: The patient in Room 18 (ID: 75384)
# Downloaded text to /content/Other Books/The patient in Room 18/pg75384.txt
# Processing book 169 of 562: On dreams (ID: 75333)
# Downloaded text to /content/Other Books/On dreams/pg75333.txt
# Processing book 170 of 562: The fireside story book (ID: 75331)
# Downloaded text to /content/Other Books/The fireside story book/pg75331.txt
# Processing book 171 of 562: The Hunterian lectures on colour-vision and colour-blindness (ID: 75519)
# Downloaded text to /content/Other Books/The Hunterian lectures on colour-vision and colour-blindness/pg75519.txt
# Processing book 172 of 562: Poppy Ott and the stuttering parrot (ID: 75550)
# Downloaded text to /content/Other Books/Poppy Ott and the stuttering parrot/pg75550.txt
# Processing book 173 of 562: Carolyn of the sunny heart (ID: 75509)
# Downloaded text to /content/Other Books/Carolyn of the sunny heart/pg75509.txt
# Processing book 174 of 562: The coins of India (ID: 75542)
# Downloaded text to /content/Other Books/The coins of India/pg75542.txt
# Processing book 175 of 562: An address to Highlanders respecting their native Gaelic :  Showing its and the broad Scotch's superiority over the artificial English for the family and the social circle, and also for lyric poetry. (ID: 75337)
# Downloaded text to /content/Other Books/An address to Highlanders respecting their native Gaelic   Showing its and the broad Scotch's superiority over the artificial English for the family and the social circle, and also for lyric poetry./pg75337.txt
# Processing book 176 of 562: Some old masters of Greek architecture (ID: 75561)
# Downloaded text to /content/Other Books/Some old masters of Greek architecture/pg75561.txt
# Processing book 177 of 562: The Dancing Faun (ID: 75492)
# Downloaded text to /content/Other Books/The Dancing Faun/pg75492.txt
# Processing book 178 of 562: The journal of George Fox, vol. 1 of 2 :  Being an historical account of his life, travels, sufferings, and Christian experiences. (ID: 75559)
# Downloaded text to /content/Other Books/The journal of George Fox, vol. 1 of 2   Being an historical account of his life, travels, sufferings, and Christian experiences./pg75559.txt
# Processing book 179 of 562: The Journal of George Fox, Vol. 2 of 2 :  Being an Historical Account of His Life, Travels, Sufferings, and Christian Experiences. (ID: 75590)
# Downloaded text to /content/Other Books/The Journal of George Fox, Vol. 2 of 2   Being an Historical Account of His Life, Travels, Sufferings, and Christian Experiences./pg75590.txt
# Processing book 180 of 562: The girls (ID: 75334)
# Downloaded text to /content/Other Books/The girls/pg75334.txt
# Processing book 181 of 562: Poems of childhood (ID: 75578)
# Downloaded text to /content/Other Books/Poems of childhood/pg75578.txt
# Processing book 182 of 562: The life and adventures of a cat (ID: 75512)
# Downloaded text to /content/Other Books/The life and adventures of a cat/pg75512.txt
# Processing book 183 of 562: Ocellus Lucanus on the nature of the universe :  Taurus, the Platonic philosopher, on the eternity of the world. Julius Firmicus Maternus of the thema mundi. Select theorems on the perpetuity of time, by Proclus. (ID: 75391)
# Downloaded text to /content/Other Books/Ocellus Lucanus on the nature of the universe   Taurus, the Platonic philosopher, on the eternity of the world. Julius Firmicus Maternus of the thema mundi. Select theorems on the perpetuity of time, by Proclus./pg75391.txt
# Processing book 184 of 562: Die drei Ostindienfahrer :  abentheuerliche Reisegeschichten (ID: 75362)
# Downloaded text to /content/Other Books/Die drei Ostindienfahrer   abentheuerliche Reisegeschichten/pg75362.txt
# Processing book 185 of 562: The Assassination Bureau, Ltd. (ID: 75562)
# Downloaded text to /content/Other Books/The Assassination Bureau, Ltd./pg75562.txt
# Processing book 186 of 562: Gustaf Fröding (ID: 75504)
# Downloaded text to /content/Other Books/Gustaf Fröding/pg75504.txt
# Processing book 187 of 562: Phil Purcel, The Pig-Driver; The Geography Of An Irish Oath; The Lianhan SheeTraits And Stories Of The Irish Peasantry, The Works ofWilliam Carleton, Volume Three (ID: 16015)
# Downloaded text to /content/Other Books/Phil Purcel, The Pig-Driver; The Geography Of An Irish Oath; The Lianhan SheeTraits And Stories Of The Irish Peasantry, The Works ofWilliam Carleton, Volume Three/pg16015.txt
# Processing book 188 of 562: The Unseen Bridegroom; Or, Wedded For a Week (ID: 15875)
# Downloaded text to /content/Other Books/The Unseen Bridegroom; Or, Wedded For a Week/pg15875.txt
# Processing book 189 of 562: Songs and lyrics of Robert Burns (ID: 75462)
# Downloaded text to /content/Other Books/Songs and lyrics of Robert Burns/pg75462.txt
# Processing book 190 of 562: Songs and lyrics of Robert Burns (ID: 75462)
# Downloaded text to /content/Other Books/Songs and lyrics of Robert Burns/pg75462.txt
# Processing book 191 of 562: Bright-Wits, Prince of Mogadore (ID: 18441)
# Downloaded text to /content/Other Books/Bright-Wits, Prince of Mogadore/pg18441.txt
# Processing book 192 of 562: The Other Man (ID: 64907)
# Downloaded text to /content/Other Books/The Other Man/pg64907.txt
# Processing book 193 of 562: The boys of Columbia High on the diamond :  or, Winning out by pluck (ID: 75400)
# Downloaded text to /content/Other Books/The boys of Columbia High on the diamond   or, Winning out by pluck/pg75400.txt
# Processing book 194 of 562: A time of terror :  the story of a great revenge (A.D., 1910) (ID: 75548)
# Downloaded text to /content/Other Books/A time of terror   the story of a great revenge (A.D., 1910)/pg75548.txt
# Processing book 195 of 562: The dangerous inheritance :  or, The mystery of the Tittani rubies (ID: 75383)
# Downloaded text to /content/Other Books/The dangerous inheritance   or, The mystery of the Tittani rubies/pg75383.txt
# Processing book 196 of 562: The King's English (ID: 75439)
# Downloaded text to /content/Other Books/The King's English/pg75439.txt
# Processing book 197 of 562: The King's English (ID: 75439)
# Downloaded text to /content/Other Books/The King's English/pg75439.txt
# Processing book 198 of 562: The journal of George Fox, vol. 1 of 2 :  Being an historical account of his life, travels, sufferings, and Christian experiences. (ID: 75559)
# Downloaded text to /content/Other Books/The journal of George Fox, vol. 1 of 2   Being an historical account of his life, travels, sufferings, and Christian experiences./pg75559.txt
# Processing book 199 of 562: The Journal of George Fox, Vol. 2 of 2 :  Being an Historical Account of His Life, Travels, Sufferings, and Christian Experiences. (ID: 75590)
# Downloaded text to /content/Other Books/The Journal of George Fox, Vol. 2 of 2   Being an Historical Account of His Life, Travels, Sufferings, and Christian Experiences./pg75590.txt
# Processing book 200 of 562: Slow Burn (ID: 59345)
# Downloaded text to /content/Other Books/Slow Burn/pg59345.txt
# Processing book 201 of 562: Eine Kindheitserinnerung des Leonardo da Vinci (ID: 75455)
# Downloaded text to /content/Other Books/Eine Kindheitserinnerung des Leonardo da Vinci/pg75455.txt
# Processing book 202 of 562: On dreams (ID: 75333)
# Downloaded text to /content/Other Books/On dreams/pg75333.txt
# Processing book 203 of 562: The incredible slingshot bombs (ID: 75427)
# Downloaded text to /content/Other Books/The incredible slingshot bombs/pg75427.txt
# Processing book 204 of 562: File No. 113 (ID: 3803)
# Downloaded text to /content/Other Books/File No. 113/pg3803.txt
# Processing book 205 of 562: The Honor of the Name (ID: 4002)
# Downloaded text to /content/Other Books/The Honor of the Name/pg4002.txt
# Processing book 206 of 562: Terror out of the past (ID: 75441)
# Downloaded text to /content/Other Books/Terror out of the past/pg75441.txt
# Processing book 207 of 562: Abracadabra & other satires (ID: 75431)
# Downloaded text to /content/Other Books/Abracadabra & other satires/pg75431.txt
# Processing book 208 of 562: From the four winds (ID: 75539)
# Downloaded text to /content/Other Books/From the four winds/pg75539.txt
# Processing book 209 of 562: The Patrician (ID: 2774)
# Downloaded text to /content/Other Books/The Patrician/pg2774.txt
# Processing book 210 of 562: Le Routier de la mer jusques au fleuve de Jourdain (ID: 75437)
# Downloaded text to /content/Other Books/Le Routier de la mer jusques au fleuve de Jourdain/pg75437.txt
# Processing book 211 of 562: Sweated industry and the minimum wage (ID: 75467)
# Downloaded text to /content/Other Books/Sweated industry and the minimum wage/pg75467.txt
# Processing book 212 of 562: Three little Trippertrots :  How they ran away and how they got back again (ID: 75474)
# Downloaded text to /content/Other Books/Three little Trippertrots   How they ran away and how they got back again/pg75474.txt
# Processing book 213 of 562: The Problem Club (ID: 75598)
# Downloaded text to /content/Other Books/The Problem Club/pg75598.txt
# Processing book 214 of 562: Ouroboros; or, the mechanical extension of mankind (ID: 75418)
# Downloaded text to /content/Other Books/Ouroboros; or, the mechanical extension of mankind/pg75418.txt
# Processing book 215 of 562: Wives and Daughters (ID: 4274)
# Downloaded text to /content/Other Books/Wives and Daughters/pg4274.txt
# Processing book 216 of 562: Barnavännen, 1905-05Illustrerad Veckotidning för de Små (ID: 27420)
# Downloaded text to /content/Other Books/Barnavännen, 1905-05Illustrerad Veckotidning för de Små/pg27420.txt
# Processing book 217 of 562: Musical Instruments, Historic, Rare and Unique (ID: 58117)
# Downloaded text to /content/Other Books/Musical Instruments, Historic, Rare and Unique/pg58117.txt
# Processing book 218 of 562: Ponies past and present (ID: 75401)
# Downloaded text to /content/Other Books/Ponies past and present/pg75401.txt
# Processing book 219 of 562: My friend Doggie; or, An only child (ID: 75465)
# Downloaded text to /content/Other Books/My friend Doggie; or, An only child/pg75465.txt
# Processing book 220 of 562: Poems (ID: 11558)
# Downloaded text to /content/Other Books/Poems/pg11558.txt
# Processing book 221 of 562: Les Vagabonds (ID: 75398)
# Downloaded text to /content/Other Books/Les Vagabonds/pg75398.txt
# Processing book 222 of 562: Ruotsin suomalaismetsiä samoilemassa :  Päiväkirjaa vuoden 1817 matkalta (ID: 75424)
# Downloaded text to /content/Other Books/Ruotsin suomalaismetsiä samoilemassa   Päiväkirjaa vuoden 1817 matkalta/pg75424.txt
# Processing book 223 of 562: Destiny (ID: 75340)
# Downloaded text to /content/Other Books/Destiny/pg75340.txt
# Processing book 224 of 562: Waste: A Tragedy, In Four Acts (ID: 15788)
# Downloaded text to /content/Other Books/Waste A Tragedy, In Four Acts/pg15788.txt
# Processing book 225 of 562: Vain Fortune: A Novel (ID: 11303)
# Downloaded text to /content/Other Books/Vain Fortune A Novel/pg11303.txt
# Processing book 226 of 562: Ladies' dress shoes of the nineteenth century (ID: 75531)
# Downloaded text to /content/Other Books/Ladies' dress shoes of the nineteenth century/pg75531.txt
# Processing book 227 of 562: The Birth of the War-God: A Poem by Kálidása (ID: 31968)
# Downloaded text to /content/Other Books/The Birth of the War-God A Poem by Kálidása/pg31968.txt
# Processing book 228 of 562: La Cour d'Assises, ses pompes et ses œuvres (ID: 75502)
# Downloaded text to /content/Other Books/La Cour d'Assises, ses pompes et ses œuvres/pg75502.txt
# Processing book 229 of 562: The heiress of McGregor :  or, Living for self (ID: 75338)
# Downloaded text to /content/Other Books/The heiress of McGregor   or, Living for self/pg75338.txt
# Processing book 230 of 562: The old Stanfield house :  or, The sin of covetousness (ID: 75576)
# Downloaded text to /content/Other Books/The old Stanfield house   or, The sin of covetousness/pg75576.txt
# Processing book 231 of 562: Rhoda's education :  or, Too much of a good thing. (ID: 75471)
# Downloaded text to /content/Other Books/Rhoda's education   or, Too much of a good thing./pg75471.txt
# Processing book 232 of 562: We of the Never-Never (ID: 4699)
# Downloaded text to /content/Other Books/We of the Never-Never/pg4699.txt
# Processing book 233 of 562: The life and adventures of a cat (ID: 75512)
# Downloaded text to /content/Other Books/The life and adventures of a cat/pg75512.txt
# Processing book 234 of 562: Die drei Ostindienfahrer :  abentheuerliche Reisegeschichten (ID: 75362)
# Downloaded text to /content/Other Books/Die drei Ostindienfahrer   abentheuerliche Reisegeschichten/pg75362.txt
# Processing book 235 of 562: Nuorten tuomio :  Yksinäytöksinen draama (ID: 75573)
# Downloaded text to /content/Other Books/Nuorten tuomio   Yksinäytöksinen draama/pg75573.txt
# Processing book 236 of 562: Onni maallinen :  Murhenäytelmä (ID: 75535)
# Downloaded text to /content/Other Books/Onni maallinen   Murhenäytelmä/pg75535.txt
# Processing book 237 of 562: Sophonisbe :  Murhenäytelmä (ID: 75355)
# Downloaded text to /content/Other Books/Sophonisbe   Murhenäytelmä/pg75355.txt
# Processing book 238 of 562: The crystal planetoids (ID: 75478)
# Downloaded text to /content/Other Books/The crystal planetoids/pg75478.txt
# Processing book 239 of 562: Das Protistenreich :  eine populäre Uebersicht über das Formengebiet der niedersten Lebewesen; Mit einem wissenschaftlichen Anhange: System der Protisten (ID: 75352)
# Downloaded text to /content/Other Books/Das Protistenreich   eine populäre Uebersicht über das Formengebiet der niedersten Lebewesen; Mit einem wissenschaftlichen Anhange System der Protisten/pg75352.txt
# Processing book 240 of 562: Rouva Meseck :  Kyläkertomus (ID: 75445)
# Downloaded text to /content/Other Books/Rouva Meseck   Kyläkertomus/pg75445.txt
# Processing book 241 of 562: Principles of electricity (ID: 75464)
# Downloaded text to /content/Other Books/Principles of electricity/pg75464.txt
# Processing book 242 of 562: The wonders of radium (ID: 75392)
# Downloaded text to /content/Other Books/The wonders of radium/pg75392.txt
# Processing book 243 of 562: The Man Without a Country (ID: 16493)
# Downloaded text to /content/Other Books/The Man Without a Country/pg16493.txt
# Processing book 244 of 562: The workwoman's guide :  containing instructions to the inexperienced in cutting out and completing those articles of wearing apparel, &c. which are ususally made at home : also, explanations on upholstery, straw-platting, bonnet-making, knitting, &c. (ID: 75494)
# Downloaded text to /content/Other Books/The workwoman's guide   containing instructions to the inexperienced in cutting out and completing those articles of wearing apparel, &c. which are ususally made at home  also, explanations on upholstery, straw-platting, bonnet-making, knitting, &c./pg75494.txt
# Processing book 245 of 562: Kosken tarina :  Kolminäytöksinen näytelmä (ID: 75405)
# Downloaded text to /content/Other Books/Kosken tarina   Kolminäytöksinen näytelmä/pg75405.txt
# Processing book 246 of 562: Corsairs of the cosmos (ID: 75438)
# Downloaded text to /content/Other Books/Corsairs of the cosmos/pg75438.txt
# Processing book 247 of 562: Aristipp in Hamburg und Altona: Ein Sitten-Gemälde neuester Zeit (ID: 55345)
# Downloaded text to /content/Other Books/Aristipp in Hamburg und Altona Ein Sitten-Gemälde neuester Zeit/pg55345.txt
# Processing book 248 of 562: Corsairs of the cosmos (ID: 75438)
# Downloaded text to /content/Other Books/Corsairs of the cosmos/pg75438.txt
# Processing book 249 of 562: Muuan katuvallankumous (ID: 75572)
# Downloaded text to /content/Other Books/Muuan katuvallankumous/pg75572.txt
# Processing book 250 of 562: The truth about the tobacco habit (ID: 75599)
# Downloaded text to /content/Other Books/The truth about the tobacco habit/pg75599.txt
# Processing book 251 of 562: The Story of My Life, volumes 1-3 (ID: 35589)
# Downloaded text to /content/Other Books/The Story of My Life, volumes 1-3/pg35589.txt
# Processing book 252 of 562: Merely the patient (ID: 75557)
# Downloaded text to /content/Other Books/Merely the patient/pg75557.txt
# Processing book 253 of 562: Yorkshire Ditties, Second SeriesTo which is added The Cream of Wit and Humourfrom his Popular Writings (ID: 17799)
# Downloaded text to /content/Other Books/Yorkshire Ditties, Second SeriesTo which is added The Cream of Wit and Humourfrom his Popular Writings/pg17799.txt
# Processing book 254 of 562: Anthropoid apes (ID: 75484)
# Downloaded text to /content/Other Books/Anthropoid apes/pg75484.txt
# Processing book 255 of 562: Hiram in the Middle West :  Or, A young farmer's upward struggle (ID: 75408)
# Downloaded text to /content/Other Books/Hiram in the Middle West   Or, A young farmer's upward struggle/pg75408.txt
# Processing book 256 of 562: The Dollar Hen (ID: 13254)
# Downloaded text to /content/Other Books/The Dollar Hen/pg13254.txt
# Processing book 257 of 562: In the Clutch of the War-God (ID: 13526)
# Downloaded text to /content/Other Books/In the Clutch of the War-God/pg13526.txt
# Processing book 258 of 562: Personal Recollections of Pardee Butler (ID: 12973)
# Downloaded text to /content/Other Books/Personal Recollections of Pardee Butler/pg12973.txt
# Processing book 259 of 562: The Gorgon's Head(From: "A Wonder-Book for Girls and Boys") (ID: 9255)
# Downloaded text to /content/Other Books/The Gorgon's Head(From A Wonder-Book for Girls and Boys)/pg9255.txt
# Processing book 260 of 562: The science of beauty, as developed in nature and applied in art (ID: 75399)
# Downloaded text to /content/Other Books/The science of beauty, as developed in nature and applied in art/pg75399.txt
# Processing book 261 of 562: Raakaleenkorjuu (ID: 75595)
# Downloaded text to /content/Other Books/Raakaleenkorjuu/pg75595.txt
# Processing book 262 of 562: Verzamelde Tooneelspelen en opstellen-over-tooneel, deel 1-2 (ID: 75358)
# Downloaded text to /content/Other Books/Verzamelde Tooneelspelen en opstellen-over-tooneel, deel 1-2/pg75358.txt
# Processing book 263 of 562: Won over :  The story of a boy's life (ID: 75351)
# Downloaded text to /content/Other Books/Won over   The story of a boy's life/pg75351.txt
# Processing book 264 of 562: Le Sud-Oranais: études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901 (ID: 75454)
# Downloaded text to /content/Other Books/Le Sud-Oranais études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901/pg75454.txt
# ...
# Processing book 479 of 562: The wonders of radium (ID: 75392)
# Downloaded text to /content/Other Books/The wonders of radium/pg75392.txt
# Processing book 480 of 562: Five Little Peppers and How They Grew (ID: 2770)
# Downloaded text to /content/Other Books/Five Little Peppers and How They Grew/pg2770.txt
# Processing book 481 of 562: Rouva Meseck :  Kyläkertomus (ID: 75445)
# Downloaded text to /content/Other Books/Rouva Meseck   Kyläkertomus/pg75445.txt
# Processing book 482 of 562: Shell shock and its lessons (ID: 75421)
# Downloaded text to /content/Other Books/Shell shock and its lessons/pg75421.txt
# Processing book 483 of 562: Isä Johannes :  kangastuskuvia keskiajan lopulta (ID: 75480)
# Downloaded text to /content/Other Books/Isä Johannes   kangastuskuvia keskiajan lopulta/pg75480.txt
# Processing book 484 of 562: Koitereen rannalla :  Yksinäytöksinen laulunäytelmä (ID: 75468)
# Downloaded text to /content/Other Books/Koitereen rannalla   Yksinäytöksinen laulunäytelmä/pg75468.txt
# Processing book 485 of 562: Luostarin metsästäjä :  Raumalainen tarina uskonpuhdistuksen ajalta (ID: 75594)
# Downloaded text to /content/Other Books/Luostarin metsästäjä   Raumalainen tarina uskonpuhdistuksen ajalta/pg75594.txt
# Processing book 486 of 562: The Lady of the Isle :  or, the Island Princess (ID: 75497)
# Downloaded text to /content/Other Books/The Lady of the Isle   or, the Island Princess/pg75497.txt
# Processing book 487 of 562: The man with a grouch (ID: 75565)
# Downloaded text to /content/Other Books/The man with a grouch/pg75565.txt
# Processing book 488 of 562: The blue book of chess :  teaching the rudiments of the game, and giving an analysis of all the recognized openings (ID: 16377)
# Downloaded text to /content/Other Books/The blue book of chess   teaching the rudiments of the game, and giving an analysis of all the recognized openings/pg16377.txt
# Processing book 489 of 562: Visibility—Zero (ID: 75566)
# Downloaded text to /content/Other Books/Visibility—Zero/pg75566.txt
# Processing book 490 of 562: Van het toovervischje :  Een oud sprookje op nieuw verteld en berijmd (ID: 75574)
# Downloaded text to /content/Other Books/Van het toovervischje   Een oud sprookje op nieuw verteld en berijmd/pg75574.txt
# Processing book 491 of 562: The soldier's orphans (ID: 75522)
# Downloaded text to /content/Other Books/The soldier's orphans/pg75522.txt
# Processing book 492 of 562: "They're a multitoode" and other stories (ID: 75460)
# Downloaded text to /content/Other Books/They're a multitoode and other stories/pg75460.txt
# Processing book 493 of 562: Plutarch's Lives, Volume 3 (of 4) (ID: 14140)
# Downloaded text to /content/Other Books/Plutarch's Lives, Volume 3 (of 4)/pg14140.txt
# Processing book 494 of 562: Slow Burn (ID: 59345)
# Downloaded text to /content/Other Books/Slow Burn/pg59345.txt
# Processing book 495 of 562: Uncle Tom's Cabin (ID: 203)
# Downloaded text to /content/Other Books/Uncle Tom's Cabin/pg203.txt
# Processing book 496 of 562: Eminent Victorians (ID: 2447)
# Downloaded text to /content/Other Books/Eminent Victorians/pg2447.txt
# Processing book 497 of 562: The Desert Moon mystery (ID: 75436)
# Downloaded text to /content/Other Books/The Desert Moon mystery/pg75436.txt
# Processing book 498 of 562: Footprints (ID: 75577)
# Downloaded text to /content/Other Books/Footprints/pg75577.txt
# Processing book 499 of 562: Les Vagabonds (ID: 75398)
# Downloaded text to /content/Other Books/Les Vagabonds/pg75398.txt
# Processing book 500 of 562: Tour of the Zero Club :  or, Adventures amid ice and snow (ID: 75342)
# Downloaded text to /content/Other Books/Tour of the Zero Club   or, Adventures amid ice and snow/pg75342.txt
# Processing book 501 of 562: The young naval captain :  The war of all nations (ID: 75394)
# Downloaded text to /content/Other Books/The young naval captain   The war of all nations/pg75394.txt
# Processing book 502 of 562: Freckles (ID: 111)
# Downloaded text to /content/Other Books/Freckles/pg111.txt
# Processing book 503 of 562: Fenella :  a novel (ID: 75372)
# Downloaded text to /content/Other Books/Fenella   a novel/pg75372.txt
# With her letters (1887-1901) and a supplementary account of her education, including passages from the reports and letters of her teacher, Anne Mansfield Sullivan, by John Albert Macy (ID: 2397)
# With her letters (1887-1901) and a supplementary account of her education, including passages from the reports and letters of her teacher, Anne Mansfield Sullivan, by John Albert Macy/pg2397.txt
# Processing book 505 of 562: Isänmaattomat :  Romaani (ID: 75336)
# Downloaded text to /content/Other Books/Isänmaattomat   Romaani/pg75336.txt
# Processing book 506 of 562: Näkymätön kirjanpitäjä (ID: 75514)
# Downloaded text to /content/Other Books/Näkymätön kirjanpitäjä/pg75514.txt
# Processing book 507 of 562: Silmä yössä :  Romaani (ID: 75406)
# Downloaded text to /content/Other Books/Silmä yössä   Romaani/pg75406.txt
# Processing book 508 of 562: A Life of Napoleon Bonaparte, with a Sketch of Josephine, Empress of the French. (ID: 59322)
# Downloaded text to /content/Other Books/A Life of Napoleon Bonaparte, with a Sketch of Josephine, Empress of the French./pg59322.txt
# Processing book 509 of 562: Ocellus Lucanus on the nature of the universe :  Taurus, the Platonic philosopher, on the eternity of the world. Julius Firmicus Maternus of the thema mundi. Select theorems on the perpetuity of time, by Proclus. (ID: 75391)
# Downloaded text to /content/Other Books/Ocellus Lucanus on the nature of the universe   Taurus, the Platonic philosopher, on the eternity of the world. Julius Firmicus Maternus of the thema mundi. Select theorems on the perpetuity of time, by Proclus./pg75391.txt
# Processing book 510 of 562: Ocellus Lucanus on the nature of the universe :  Taurus, the Platonic philosopher, on the eternity of the world. Julius Firmicus Maternus of the thema mundi. Select theorems on the perpetuity of time, by Proclus. (ID: 75391)
# Downloaded text to /content/Other Books/Ocellus Lucanus on the nature of the universe   Taurus, the Platonic philosopher, on the eternity of the world. Julius Firmicus Maternus of the thema mundi. Select theorems on the perpetuity of time, by Proclus./pg75391.txt
# Processing book 511 of 562: Trading with Mexico (ID: 75469)
# Downloaded text to /content/Other Books/Trading with Mexico/pg75469.txt
# Processing book 512 of 562: The old Worcester jug :  or, John Griffin's little maid (ID: 75600)
# Downloaded text to /content/Other Books/The old Worcester jug   or, John Griffin's little maid/pg75600.txt
# Processing book 513 of 562: The life of Henry Labouchere (ID: 75377)
# Downloaded text to /content/Other Books/The life of Henry Labouchere/pg75377.txt
# Processing book 514 of 562: Early western travels, 1748-1846, Volume 2 (of 2) (ID: 75593)
# Downloaded text to /content/Other Books/Early western travels, 1748-1846, Volume 2 (of 2)/pg75593.txt
# Processing book 515 of 562: Hiram in the Middle West :  Or, A young farmer's upward struggle (ID: 75408)
# Downloaded text to /content/Other Books/Hiram in the Middle West   Or, A young farmer's upward struggle/pg75408.txt
# Processing book 516 of 562: Die drei Ostindienfahrer :  abentheuerliche Reisegeschichten (ID: 75362)
# Downloaded text to /content/Other Books/Die drei Ostindienfahrer   abentheuerliche Reisegeschichten/pg75362.txt
# Processing book 517 of 562: La puritaine et l'amour (ID: 75433)
# Downloaded text to /content/Other Books/La puritaine et l'amour/pg75433.txt
# Processing book 518 of 562: Deirdre wed and other poems (ID: 75529)
# Downloaded text to /content/Other Books/Deirdre wed and other poems/pg75529.txt
# Processing book 519 of 562: Electric railways (ID: 75289)
# Downloaded text to /content/Other Books/Electric railways/pg75289.txt
# Processing book 520 of 562: The basket maker (ID: 75361)
# Downloaded text to /content/Other Books/The basket maker/pg75361.txt
# Processing book 521 of 562: Sun Dog loot (ID: 75347)
# Downloaded text to /content/Other Books/Sun Dog loot/pg75347.txt
# Processing book 522 of 562: Alonzo Fitz, and Other Stories (ID: 3184)
# Downloaded text to /content/Other Books/Alonzo Fitz, and Other Stories/pg3184.txt
# Processing book 523 of 562: Those Extraordinary Twins (ID: 3185)
# Downloaded text to /content/Other Books/Those Extraordinary Twins/pg3185.txt
# Processing book 524 of 562: Scotch marriages, vol. 1 (ID: 75486)
# Downloaded text to /content/Other Books/Scotch marriages, vol. 1/pg75486.txt
# Processing book 525 of 562: Vida de Don Quijote y Sancho (ID: 75472)
# Downloaded text to /content/Other Books/Vida de Don Quijote y Sancho/pg75472.txt
# Processing book 526 of 562: A book of dear dead women (ID: 75516)
# Downloaded text to /content/Other Books/A book of dear dead women/pg75516.txt
# Processing book 527 of 562: Famous stories from foreign countries (ID: 75466)
# Downloaded text to /content/Other Books/Famous stories from foreign countries/pg75466.txt
# Processing book 528 of 562: Monsieur Teste (ID: 75440)
# Downloaded text to /content/Other Books/Monsieur Teste/pg75440.txt
# Processing book 529 of 562: The roving critic (ID: 75524)
# Downloaded text to /content/Other Books/The roving critic/pg75524.txt
# Processing book 530 of 562: Poems (ID: 75527)
# Downloaded text to /content/Other Books/Poems/pg75527.txt
# Processing book 531 of 562: Barnavännen, 1905-05Illustrerad Veckotidning för de Små (ID: 27420)
# Downloaded text to /content/Other Books/Barnavännen, 1905-05Illustrerad Veckotidning för de Små/pg27420.txt
# Processing book 532 of 562: Blackwood's Edinburgh Magazine, Vol. 67, No. 413, March, 1850 (ID: 75498)
# Downloaded text to /content/Other Books/Blackwood's Edinburgh Magazine, Vol. 67, No. 413, March, 1850/pg75498.txt
# Processing book 533 of 562: Blackwood's Edinburgh Magazine, Vol. 67, No. 415, May, 1850 (ID: 75515)
# Downloaded text to /content/Other Books/Blackwood's Edinburgh Magazine, Vol. 67, No. 415, May, 1850/pg75515.txt
# Processing book 534 of 562: Chambers's Edinburgh Journal, No. 425Volume 17, New Series, February 21, 1852 (ID: 16924)
# Downloaded text to /content/Other Books/Chambers's Edinburgh Journal, No. 425Volume 17, New Series, February 21, 1852/pg16924.txt
# Processing book 535 of 562: Chambers's Journal of Popular Literature, Science, and Art, fifth series, no. 149, vol. III, November 6, 1886 (ID: 75449)
# Downloaded text to /content/Other Books/Chambers's Journal of Popular Literature, Science, and Art, fifth series, no. 149, vol. III, November 6, 1886/pg75449.txt
# Processing book 536 of 562: The Delinquent, Vol. IV, No. 8, August, 1914 (ID: 75368)
# Downloaded text to /content/Other Books/The Delinquent, Vol. IV, No. 8, August, 1914/pg75368.txt
# Processing book 537 of 562: The sprightly romance of Marsac (ID: 75477)
# Downloaded text to /content/Other Books/The sprightly romance of Marsac/pg75477.txt
# Processing book 538 of 562: Suurvallat I :  Piirteitä nykyajan suurpolitiikasta (ID: 75597)
# Downloaded text to /content/Other Books/Suurvallat I   Piirteitä nykyajan suurpolitiikasta/pg75597.txt
# Processing book 539 of 562: The puzzle of life and how it has been put together :  A short history of the formation of the earth, with its vegetable and animal life, from the earliest times, including an account of prehistoric man, his weapons, tools, and works (ID: 75564)
# Downloaded text to /content/Other Books/The puzzle of life and how it has been put together   A short history of the formation of the earth, with its vegetable and animal life, from the earliest times, including an account of prehistoric man, his weapons, tools, and works/pg75564.txt
# Processing book 540 of 562: Mémoires de Constant, premier valet de chambre de l'empereur, sur la vie privée de Napoléon, sa famille et sa cour. (ID: 28176)
# Downloaded text to /content/Other Books/Mémoires de Constant, premier valet de chambre de l'empereur, sur la vie privée de Napoléon, sa famille et sa cour./pg28176.txt
# Processing book 541 of 562: Työlakko :  Näytelmä kolmessa näytöksessä (ID: 75496)
# Downloaded text to /content/Other Books/Työlakko   Näytelmä kolmessa näytöksessä/pg75496.txt
# Processing book 542 of 562: The process of gilding and bronzing picture frames (ID: 75345)
# Downloaded text to /content/Other Books/The process of gilding and bronzing picture frames/pg75345.txt
# Processing book 543 of 562: The dark eyes of London (ID: 75589)
# Downloaded text to /content/Other Books/The dark eyes of London/pg75589.txt
# Processing book 544 of 562: The Other Man (ID: 64907)
# Downloaded text to /content/Other Books/The Other Man/pg64907.txt
# Processing book 545 of 562: An account of the giants lately discovered :  In a letter to a friend in the country (ID: 75432)
# Downloaded text to /content/Other Books/An account of the giants lately discovered   In a letter to a friend in the country/pg75432.txt
# Processing book 546 of 562: Was I right? (ID: 75393)
# Downloaded text to /content/Other Books/Was I right/pg75393.txt
# Processing book 547 of 562: Dimple Dallas :  The further fortunes of a sweet little maid (ID: 75380)
# Downloaded text to /content/Other Books/Dimple Dallas   The further fortunes of a sweet little maid/pg75380.txt
# Processing book 548 of 562: The Gutenberg Webster's Unabridged Dictionary: Section I, J, K, and L (ID: 664)
# Downloaded text to /content/Other Books/The Gutenberg Webster's Unabridged Dictionary Section I, J, K, and L/pg664.txt
# Processing book 549 of 562: Der Skorpion. Band 1 (ID: 75397)
# Downloaded text to /content/Other Books/Der Skorpion. Band 1/pg75397.txt
# Processing book 550 of 562: A Gentleman of France: Being the Memoirs of Gaston de Bonne Sieur de Marsac (ID: 1939)
# Downloaded text to /content/Other Books/A Gentleman of France Being the Memoirs of Gaston de Bonne Sieur de Marsac/pg1939.txt
# Processing book 551 of 562: Archimedes; or, the future of physics (ID: 75452)
# Downloaded text to /content/Other Books/Archimedes; or, the future of physics/pg75452.txt
# Processing book 552 of 562: Principles and practice of agricultural analysis. Volume 3 (of 3), Agricultural products (ID: 75389)
# Downloaded text to /content/Other Books/Principles and practice of agricultural analysis. Volume 3 (of 3), Agricultural products/pg75389.txt
# Processing book 553 of 562: The incredible slingshot bombs (ID: 75427)
# Downloaded text to /content/Other Books/The incredible slingshot bombs/pg75427.txt
# Processing book 554 of 562: Cedar chests, how to make them (ID: 75563)
# Downloaded text to /content/Other Books/Cedar chests, how to make them/pg75563.txt
# Processing book 555 of 562: Maisie's merry Christmas (ID: 75482)
# Downloaded text to /content/Other Books/Maisie's merry Christmas/pg75482.txt
# Processing book 556 of 562: Fish preferred (ID: 75435)
# Downloaded text to /content/Other Books/Fish preferred/pg75435.txt
# Processing book 557 of 562: The play's the thing (ID: 75451)
# Downloaded text to /content/Other Books/The play's the thing/pg75451.txt
# Processing book 558 of 562: The Mercer Boys' Cruise in the Lassie (ID: 55335)
# Downloaded text to /content/Other Books/The Mercer Boys' Cruise in the Lassie/pg55335.txt
# Processing book 559 of 562: Henrietta's Wish; Or, Domineering (ID: 5124)
# Downloaded text to /content/Other Books/Henrietta's Wish; Or, Domineering/pg5124.txt
# Processing book 560 of 562: The Racer boys on the prairies :  The treasure of Golden Peak (ID: 75395)
# Downloaded text to /content/Other Books/The Racer boys on the prairies   The treasure of Golden Peak/pg75395.txt
# Processing book 561 of 562: Le Sud-Oranais: études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901 (ID: 75454)
# Downloaded text to /content/Other Books/Le Sud-Oranais études floristiques et phytogéographiques faites au cours d'une exploration dans le Sud-Ouest de l'Algérie en 1901/pg75454.txt
# Processing book 562 of 562: Vildsomme Veje :  Ogsaa en kærlighedshistorie / I sommerferien (ID: 75414)
# Downloaded text to /content/Other Books/Vildsomme Veje   Ogsaa en kærlighedshistorie  I sommerferien/pg75414.txt
# CSV file created at /content/gutenberg_recent_books.csv
# Downloaded 561 out of 562 books
